# %% [markdown]
# <a href="https://colab.research.google.com/github/liturriago/Portafolio_ONE/blob/main/Modulo3/cuadernos/Flujo_GAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Logo UNAL CHEC](https://github.com/UN-GCPDS/curso_IA_CHEC/blob/main/logo_unal_chec.jpg?raw=1)
#
# # **MÓDULO 3: APRENDIZAJE PROFUNDO**
#
# ## **Descripción**
#
# Aplicación de redes neuronales para la simulación y predicciones de flujos de la red gasífera de Colombia.
#
# ### **Profesor - Sesión 5 y 6:** Diego Armando Pérez Rosero
# ### **Monitores - Sesión 5 y 6:** Danna Valentina Salazar Dubois, Juan Camilo Lugo Rojas y Lucas Miguel Iturriago Salas

# %%
# @title Configurar entorno
# %%capture
# !pip uninstall -y tensorflow tf-keras
# !pip install tensorflow==2.15.1
# !pip install visualkeras
# !pip install spektral
# !pip -q install torch_geometric
# !git clone https://github.com/UN-GCPDS/curso_IA_CHEC.git

from tensorflow.python.ops.nn_ops import softmax
from keras import backend as k
import numpy as np
from matplotlib.gridspec import GridSpec
from IPython import display
from scipy.optimize import linprog
from sklearn.metrics import mean_squared_error,mean_absolute_error,mean_absolute_percentage_error
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.layers import Activation,Dense,Input,BatchNormalization,Dropout,Conv1D,Flatten,MaxPool1D,Dot,Reshape,Conv2D,Concatenate,ReLU,Lambda,MaxPooling2D,Normalization,Reshape
import cvxpy as cp
import tensorflow as tf
from keras import Model
from IPython import display
from tensorflow.keras import layers
from tensorflow.keras import regularizers
import warnings
import os
import pandas as pd
from IPython import display
path='/content/curso_IA_CHEC/Modulo3/database/'
from keras.models import Sequential
mse=mean_squared_error
mae=mean_absolute_error
mape=mean_absolute_percentage_error
warnings.filterwarnings("ignore")
from scipy.sparse import coo_matrix, eye, hstack
from tensorflow.keras.callbacks import Callback
import torch
from torch_geometric.utils import to_dense_adj
from spektral.layers import GCNConv
import pandas as pd
import scipy.io as sio
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler,StandardScaler
import time
from keras.callbacks import Callback
import seaborn as sns
import os
from pathlib import Path
import scipy.io as sio

import ipywidgets as widgets
from IPython.display import display, clear_output


def model_op(loss: str ='huber') -> Model:
    """
    Create a Keras model with a set of dense layers and custom regularization.

    Returns:
        A Keras Model object.
    """
    input_tensor = Input(shape=(2,))
    regularization_strength = 1e-1
    learning_rate = 1e-3
    layer = input_tensor
    for i in range(1, 5):
        layer = Dense(
            32,
            activation='selu',
            kernel_regularizer=regularizers.L1L2(
                l1=regularization_strength,
                l2=regularization_strength
            ),
            name=f'Dense_{i}'
        )(layer)

    weights = Dense(
        2,
        activation='selu',
        kernel_regularizer=regularizers.L1L2(
            l1=regularization_strength,
            l2=regularization_strength
        ),
        name='W',
        kernel_constraint=tf.keras.constraints.MaxNorm(1)
    )(layer)

    output_tensor = tf.reduce_sum(tf.multiply(weights, input_tensor), axis=-1)
    output_tensor = Reshape((1,))(output_tensor)
    model = Model(inputs=input_tensor, outputs=output_tensor)
    model.compile(loss = loss, optimizer=tf.keras.optimizers.Adam(learning_rate))
    return model

def GenW(Data_inf,Data_W,Data_T,Data_C,Data_Dc,Data_sto):
    N = len(Data_inf)
    W = len(Data_W)
    wells = coo_matrix((np.ones(W, ), (Data_W['node'] - 1, np.arange(W))), shape=(N, W))
    P = len(Data_T)
    data = np.concatenate((-1.0 * np.ones(P), np.ones(P)))
    row = pd.concat((Data_T['fnode'] - 1, Data_T['tnode'] - 1))
    col = np.concatenate(2 * [np.arange(P)])

    pipes = coo_matrix((data, (row, col)), shape=(N, P))

    C = len(Data_C)
    data = np.concatenate((-1.0 * np.ones(C), np.ones(C)))
    row = pd.concat((Data_C['fnode'] - 1, Data_C['tnode'] - 1))
    col = np.concatenate(2 * [np.arange(C)])
    comps = coo_matrix((data, (row, col)), shape=(N, C))
    users=hstack(len(Data_Dc.T) * [eye(N)])
    S = len(Data_sto)
    sto = coo_matrix((np.ones(S, ), (Data_sto['node'] - 1, np.arange(S))), shape=(N, S))
    sto = hstack([sto, -1.0 * sto])
    w=(hstack((wells, pipes, comps, users, sto))).toarray()
    return w

def split(F_d,F_O):
    y=F_O
    X_train,X_test,y_train, y_test = train_test_split(F_d,y,test_size=0.2)
    return X_train,X_test,y_train, y_test


def flow(C,li,name,e,initializer):
    #D=Dense(1024,activation='selu',kernel_initializer=initializer)(C)
    D=BatchNormalization()(C)
    D=Dense(len(li),name=name,activation=e,kernel_initializer=initializer)(D)

    return D
def pres(C,li,ls,name,initializer):
    D=BatchNormalization()(C)
    D=Dense(len(li),name=name,activation=custom_activation1(li,ls),kernel_initializer=initializer)(C)
    return D

def Flujos(model,X_test):
    model_B = tf.keras.Model(inputs=model.inputs,outputs=model.get_layer('Flujos').output)
    F=model_B.predict(X_test,verbose=False)
    return F

class custom_activation1:
    def __init__(self, lower_bound, upper_bound):
        self.li=tf.cast(lower_bound, tf.float32)
        self.ls=tf.cast(upper_bound, tf.float32)

    def __call__(self, x):
        x=tf.cast(x, tf.float32)
        x=tf.sigmoid(x)*(self.ls-self.li)+self.li
        return x

    def get_config(self):
        return {
            "lower_bound": self.li,
            "upper_bound": self.ls
        }

    @classmethod
    def from_config(cls, config):
        return cls(**config)

class LRReducer(Callback):
    def __init__(self, epoch_threshold):
        super(LRReducer, self).__init__()
        self.epoch_threshold = epoch_threshold

    def on_epoch_begin(self, epoch, logs=None):
        if epoch in self.epoch_threshold:
            lr = float(self.model.optimizer.lr)
            new_lr = lr * 0.1
            self.model.optimizer.lr.assign(new_lr)

class WellDense(tf.keras.layers.Layer):
    def __init__(self, well=80.0, **kwargs):
        super(WellDense, self).__init__(**kwargs)
        self.well = tf.Variable(initial_value=well, trainable=False, dtype=tf.float32)
    def call(self, inputs):
        x = inputs
        w = tf.reduce_sum(x, axis=1, keepdims=True)
        w = tf.where(w >= self.well, self.well, w)
        return w
    def get_config(self):
        config = super(WellDense, self).get_config()
        config.update({"well": self.well.numpy()})
        return config
    @classmethod
    def from_config(cls, config):
        return cls(**config)


class RestrictedDense(tf.keras.layers.Layer):
    def __init__(self, initializer, well, units, **kwargs):
        super().__init__(**kwargs)
        self.initializer = initializer
        self.units = units
        self.well = tf.constant(well, dtype=tf.float32)


    def call(self, inputs):
        x, In, fw = inputs
        x = tf.where(x <= 0., 0., x)
        x = tf.where(x <= In, x, In)
        mask = tf.where(tf.reduce_sum(In, axis=-1, keepdims=True) <= self.well, 0.0, 1.0)
        x = x * mask
        return x

    def get_config(self):
        config = super().get_config()
        config.update({
            "initializer": tf.keras.initializers.serialize(self.initializer),
            "well": self.well,
            "units": self.units
        })
        return config
    @classmethod
    def from_config(cls, config):
        config['initializer'] = tf.keras.initializers.deserialize(config['initializer'])
        return cls(**config)

class custom_loss2(tf.keras.losses.Loss):
    def __init__(self, Kt, i, j, Bc, ic, jc, find=6, s=0, name="Wey"):
        super().__init__(name=name)
        self.Kt = Kt
        self.i = i
        self.j = j
        self.Bc = Bc
        self.ic = ic
        self.jc = jc
        self.find = find
        self.s = s
        self.lower_bound = tf.constant(1.0, dtype=tf.float32)
        self.upper_bound = tf.constant(Bc, dtype=tf.float32)

    def call(self, y_true, y_pred):
        f = tf.cast(y_pred[:, :self.find], tf.float32)
        P = tf.cast(y_pred[:, self.find:], tf.float32)
        pi = tf.gather(P, self.i, axis=1)
        pj = tf.gather(P, self.j, axis=1)
        loss = tf.keras.losses.huber(f, tf.sign(pi**2-pj**2)*tf.sqrt(self.Kt*tf.abs(pi**2-pj**2)))

        P_ic = tf.gather(P, self.ic, axis=1)
        P_jc = tf.gather(P, self.jc, axis=1)
        h = self.upper_bound + self.lower_bound
        h1 = self.upper_bound - self.lower_bound
        PjPi = tf.math.divide_no_nan(P_jc, P_ic)  # Asumiendo que P_jc y P_ic están definidos
        PjPi_rounded = tf.round(PjPi * 1000) / 1000
        condition = tf.math.logical_and(  PjPi  >= self.lower_bound,PjPi <= self.upper_bound)
        Penalty = tf.reduce_mean(tf.where(condition, 0.0, tf.square((PjPi-0.5*h)/h1)))
        return loss
class custom_loss3(tf.keras.losses.Loss):
    def __init__(self, Kt, i, j, Bc, ic, jc, find=6, s=0, name="Ratio"):
        super().__init__(name=name)
        self.Kt = Kt
        self.i = i
        self.j = j
        self.Bc = Bc
        self.ic = ic
        self.jc = jc
        self.find = find
        self.s = s
        self.lower_bound = tf.constant(1.0, dtype=tf.float32)
        self.upper_bound = tf.constant(Bc, dtype=tf.float32)

    def call(self, y_true, y_pred):
        f = tf.cast(y_pred[:, :self.find], tf.float32)
        P = tf.cast(y_pred[:, self.find:], tf.float32)
        pi = tf.gather(P, self.i, axis=1)
        pj = tf.gather(P, self.j, axis=1)
        loss = tf.keras.losses.huber(f, tf.sign(pi**2-pj**2)*tf.sqrt(self.Kt*tf.abs(pi**2-pj**2)))

        P_ic = tf.gather(P, self.ic, axis=1)
        P_jc = tf.gather(P, self.jc, axis=1)
        h = self.upper_bound + self.lower_bound
        h1 = self.upper_bound - self.lower_bound
        PjPi = tf.math.divide_no_nan(P_jc, P_ic)  # Asumiendo que P_jc y P_ic están definidos
        PjPi_rounded = tf.round(PjPi * 1000) / 1000
        condition = tf.math.logical_and(  PjPi  >= self.lower_bound,PjPi <= self.upper_bound)
        Penalty = tf.reduce_mean(tf.where(condition, 0.0, tf.square((PjPi-0.5*h)/h1)))
        return Penalty

    def get_config(self):
        return {
            "Kt": self.Kt,
            "i": self.i,
            "j": self.j,
            "Bc": self.Bc,
            "ic": self.ic,
            "jc": self.jc,
            "find": self.find,
            "s": self.s
        }
    @classmethod
    def from_config(cls, config):
        return cls(**config)



class FixedWeightsConstraint(tf.keras.constraints.Constraint):
    def __init__(self, w):
        self.w = tf.constant(w.T, dtype=tf.float32)  # Asegúrate de que `w` está en el formato correcto antes de convertirlo a un tensor.

    def __call__(self, weights):
        return self.w

    def get_config(self):
        return {"w": self.w.numpy().tolist()}  # Convierte el tensor a lista para la serialización.

    @classmethod
    def from_config(cls, config):
        return cls(w=config["w"])


def mish(x):
    return x*tf.math.tanh(tf.math.softplus(x))
def swish(x):
    return x*tf.sigmoid(x)


def flow_model(path, fd,U1,U2,a,b,c, s=1,G=1):
    """
    Builds and compiles a TensorFlow Keras model based on data from an Excel file and additional parameters.

    Parameters:
    - path (str): Path to the Excel file containing the model's data.
    - fd (array-like): Additional flow data for the model.
    - seeds (int): Seed for random number generation for reproducibility.
    - s (int): Mode switch for the model configuration.

    Returns:
    - tensorflow.keras.Model: The compiled Keras model.
    """
    Data_inf  =   pd.read_excel(path, sheet_name='node.info')
    Data_D    =   pd.read_excel(path, sheet_name='node.dem')
    Data_Dc   =   pd.read_excel(path, sheet_name='node.demcost')
    Data_W    =   pd.read_excel(path, sheet_name='well')
    Data_T    =   pd.read_excel(path, sheet_name='pipe')
    Data_C    =   pd.read_excel(path, sheet_name='comp')
    Data_sto  =   pd.read_excel(path, sheet_name='sto')
    w = GenW(Data_inf, Data_W, Data_T, Data_C, Data_Dc, Data_sto)
    N = w.shape[0]
    initializer = tf.keras.initializers.GlorotNormal()
    In = Input(shape=(N,))
    N1 = N
    edge_index = torch.tensor([[0, 3, 3, 4, 5, 4, 1, 2],
                           [1, 4, 5, 5, 6, 7, 2, 3]], dtype=torch.long)
    A = to_dense_adj(edge_index)[0].numpy().astype(int)
    N1 = N
    A = tf.convert_to_tensor(A)
    if G==0:
        x=Dense(w.shape[1]*4,'selu',kernel_regularizer=regularizers.L1L2(a,a))(In)
    else:
        x=Reshape((N,1))(In)
        x=GCNConv(w.shape[1]*4,'selu',)([x,A])
        x=Flatten()(x)

    F = []
    if s == 0:
        Li = np.concatenate((Data_T['Fg_min'].values, [0] * len(Data_C), Data_D['Res'].values * 0.0, Data_D['Ind'].values * 0.0, Data_D['Com'].values * 0.0,
                            Data_D['NGV'].values * 0.0, Data_D['Ref'].values*0.0,
                            Data_D['Pet'].values * 0.0, [0] * len(Data_sto.values) * 2))
        Ls = np.concatenate((Data_T['Fg_max'].values, Data_C['fmaxc'].values, fd, Data_D['Ind'].values * 0.0, Data_D['Com'].values * 0.0, Data_D['NGV'].values * 0.0, Data_D['Ref'].values * 0.0, Data_D['Pet'].values * 0.0,
                            (Data_sto['V0'].values - Data_sto['V_max'].values) * 0.0, (Data_sto['Vmax'].values - Data_sto['V0'].values) * 0.0))
        F = []
        F0 = WellDense(well=Data_W['Imax'].values[0], name='F_0')(In)
        F1 = flow(x,Li,'F_1',custom_activation1(Li,Ls),initializer)
        F = Concatenate(name='F')([F0, F1])  # ,F2,F3])

    elif s == 1:
        fdin = len(Data_W['Imin'].values) + \
            len([0] * len(Data_T)) + len([0] * len(Data_C))
        fdfn = len([0] * len(Data_sto.values) * 2) + \
            len(Data_inf['Pmin'].values)
        F0 = WellDense(well=Data_W['Imax'].values[0], name='F_0')(In)
        Li = Data_T['Fg_min'].values
        Ls = Data_T['Fg_max'].values
        F1 =flow(x,Li,'F_1',custom_activation1(Li,Ls),initializer)

        Li = [0] * len(Data_C)
        Ls = Data_C['fmaxc'].values
        F2 = flow(x,Li,'F_2',custom_activation1(Li,Ls),initializer)
        xt=Dense(N1,'selu',kernel_regularizer=regularizers.L1L2(b,b),kernel_initializer=initializer)(x)
        xt=BatchNormalization()(xt)
        F3 = RestrictedDense(
            initializer=initializer, well=Data_W['Imax'].values[0], name='F_3', units=len(Data_inf))([xt, In, F0])
        Li=np.concatenate((Data_D['Ind'].values*0.0,Data_D['Com'].values*0.0,Data_D['NGV'].values*0.0,Data_D['Ref'].values*0.0,
                        Data_D['Pet'].values*0.0,[0]*len(Data_sto.values)*2))
        Ls=np.concatenate((Data_D['Ind'].values*0.0,Data_D['Com'].values*0.0,Data_D['NGV'].values*0.0,Data_D['Ref'].values*0.0,Data_D['Pet'].values*0.0,
                    (Data_sto['V0'].values-Data_sto['V_max'].values)*0.0,(Data_sto['Vmax'].values-Data_sto['V0'].values)*0.0))
        F4=flow(In,Li,'F_4',custom_activation1(Li,Ls),initializer)
        F = Concatenate(name='F')([F0, F1, F2, F3, F4])

    Out1=Dense(units=w.shape[0],use_bias=False,kernel_constraint=FixedWeightsConstraint(w),name='Bal')(F)

    Kt=tf.constant(Data_T['Kij'].values,dtype=tf.float32)
    i=Data_T['fnode'].values-1
    j=Data_T['tnode'].values-1
    ftin=len(Data_W)
    ftfn=len(Data_T)
    f=F[:,ftin:ftfn+ftin]
    Li=Data_inf['Pmin'].values
    Ls=Data_inf['Pmax'].values
    ib=Data_C['fnode'].values-1
    jb=Data_C['tnode'].values-1


    if G==0:
        x1=Dense(w.shape[1]*4,'selu',kernel_regularizer=regularizers.L1L2(c,c),kernel_initializer=initializer)(In)
        x1=BatchNormalization()(x1)
    else:
        x=Reshape((-1,1))(F1)
        x1=Flatten()(x)
        x1=Dense(w.shape[1]*4,'selu',kernel_regularizer=regularizers.L1L2(c,c),kernel_initializer=initializer)(F1)
        x1=BatchNormalization()(x1)
        #x=GCNConv(8,'selu')([x,A])


        #x1=Dense(w.shape[1]*4,'selu',kernel_regularizer=regularizers.L1L2(c,c),kernel_initializer=initializer)(x1)
        #x1=BatchNormalization()(x1)

    #x1=Dense(N1,'sigmoid',kernel_regularizer=regularizers.L1L2(c,c),kernel_initializer=initializer)(x1)
    #x1=BatchNormalization()(x1)
    P =pres(x1,Li,Ls,'P',initializer)

    Out2 = Concatenate(name='Wey')([f, P])
    Out3 = Concatenate(name='Ratio')([f, P])
    Bc = Data_C['ratio'].values

    model = Model(In, [Out1, Out2,Out3])
    model.compile(loss={'Bal': 'huber', 'Wey': custom_loss2(Kt,i,j,Bc,ib,jb,ftfn),'Ratio': custom_loss3(Kt,i,j,Bc,ib,jb,ftfn)},
                  optimizer=tf.keras.optimizers.Adamax(1e-2), loss_weights=[0.6, 0.1,0.3])
    return model


class TimeHistory(Callback):
    def on_train_begin(self, logs=None):
        self.times = []

    def on_epoch_begin(self, epoch, logs=None):
        self.epoch_time_start = time.time()

    def on_epoch_end(self, epoch, logs=None):
        self.times.append(time.time() - self.epoch_time_start)

def EvalBalance(FT,W,X):
    aux1=[]
    aux2=[]
    for i in range(len(FT[0])):
        aux1.append(mape(X[i],FT[0][i]@W.T))
        aux2.append(mape(X[i],FT[1][i]@W.T))
    return[aux1,aux2]

def EvalWeymouth(X,Y):
    aux1=[]
    aux2=[]
    for i in range(len(X[0])):
        aux1.append(mape(X[0][i],Y[0][i]))
        aux2.append(mape(X[1][i],Y[1][i]))
    return[aux1,aux2]

def EvalCost(X,Y):
    aux1=[]
    for i in range(len(X)):
        aux1.append(Y[i] - X[i])
    return aux1

def dividir_datos(array, indice_test):
    """
    Divide un array en conjuntos de entrenamiento y prueba basado en un índice dado y
    reorganiza el conjunto de entrenamiento a una nueva forma.

    Parámetros:
    - array: Array de entrada con dimensiones (10, 100, 8).
    - indice_test: Índice del sub-array a usar como conjunto de prueba.
a
    Retorna:
    - X_train_reshaped: Array con los datos de entrenamiento reorganizados.
    - X_test: Array con los datos de prueba.
    """
    # Verificar que el índice esté en el rango permitido
    if indice_test < 0 or indice_test >= array.shape[0]:
        raise ValueError("El índice debe estar entre 0 y 9.")

    # Usar el índice para seleccionar el conjunto de prueba y el resto para entrenamiento
    X_test = array[indice_test]
    X_train = np.delete(array, indice_test, axis=0)

    # Cambiar la forma de X_train de (9, 100, 8) a (900, 8)
    X_train_reshaped = np.concatenate(X_train)
    return X_train_reshaped, X_test

def print_model_summary_with_memory(model):
    model.summary()  # Imprimir el resumen estándar

    total_memory = 0
    print("\n{:<20} {:<15}".format("Layer", "Memory (MB)"))
    print("="*35)

    # Iterar sobre cada capa y calcular la memoria usada por los pesos
    for layer in model.layers:
        layer_memory = 0
        for weight in layer.get_weights():
            layer_memory += weight.nbytes/1024  # Convertir bytes a MB
        total_memory += layer_memory
        print("{:<20} {:<15.2f}".format(layer.name, layer_memory))

    print("="*35)
    print(f"Total memory usage: {total_memory:.2f} KB")

# %% [markdown]
# ## **Objetivo**:
# Implementar técnicas de deep learning para optimizar sistemas de potencia alimentados por plantas termoeléctricas, utilizando redes neuronales informadas por principios físicos.

# %% [markdown]
# ![Red completa](https://github.com/UN-GCPDS/curso_IA_CHEC/blob/main/Modulo3/sources/red_completa.png?raw=1)

# %% [markdown]
# ## **Optimización Lineal y No Lineal para Sistemas a Gas**

# %% [markdown]
# <img src="https://github.com/UN-GCPDS/curso_IA_CHEC/blob/main/Modulo3/sources/Diagrama.svg?raw=1" alt="Red completa" width="700">

# %% [markdown]
# Sistema a gas dependiente de flujo y presión
#
# \begin{aligned}
#     & \min_{\mathbf{x},\boldsymbol{\pi}} \quad  \mathbf{x}^\top\mathbf{a} \\
#     & \text{s.t.} \quad  \quad \mathbf{B}\mathbf{x}=\mathbf{z}\\
#     & \quad \quad \quad x_q=\text{sgn}\left(\pi_{w(q)}^{2}-\pi_{w'(q)}^{2}\right)\sqrt{k_q|\pi_{w(q)}^{2}-\pi_{w'(q)}^{2}|},\\
#     & \quad \quad \quad \forall q\in Q; \quad w(q),w'(q)\in W\\
#     & \quad \quad \quad {\beta}_{\text{min}}(n,n')\leq\frac{\pi_n}{\pi_{n'}}\leq {\beta}_{\text{max}}(n,n'), \quad \forall n,n'\in V\\
#     & \quad \quad \quad \boldsymbol{\gamma}_{\text{min}}\leq \boldsymbol{\pi} \leq  \boldsymbol{\gamma}_{\text{max}}\\
#     & \quad \quad \quad \boldsymbol{\delta}_{\text{min}}\leq \mathbf{x}\leq \boldsymbol{\delta}_{\text{max}},
# \end{aligned}
#
#
# ---
#
# Donde $\mathbf{a} \in \mathbb{R}^{P}$, $\mathbf{x} \in \mathbb{R}^{P}$, $\mathbf{B} \in \mathbb{R}^{W \times P}$, $\mathbf{z} \in \mathbb{R}^{W}$, $\boldsymbol{\pi} \in \mathbb{R}^{W}$, $k_q\in\mathbb{R}$, $\pi_{w(q)}, \pi_{n}, \pi_{n'} \in \boldsymbol{\pi}$, ${\beta}_{\text{min}}(n,n'), {\beta}_{\text{max}}(n,n') \in \mathbb{R}^+$, $\boldsymbol{\gamma}_{\text{min}}, \boldsymbol{\gamma}_{\text{max}} \in \mathbb{R}^{W}$ y $\boldsymbol{\delta}_{\text{min}}, \boldsymbol{\delta}_{\text{max}} \in \mathbb{R}^{P}$.

# %% [markdown]
# <table style="background-color: white; border-collapse: collapse;">
#   <tr>
#     <td style="background-color: white;">
#       <img src="https://github.com/UN-GCPDS/curso_IA_CHEC/blob/main/Modulo3/sources/red_ocho_nodos.png?raw=1" alt="Imagen 1" width="400"/>
#     </td>
#     <td style="background-color: white;">
#       <img src="https://github.com/UN-GCPDS/curso_IA_CHEC/blob/main/Modulo3/sources/red_gasifera_colombia.png?raw=1" alt="Imagen 2" width="400"/>
#     </td>
#   </tr>
# </table>

# %%
# @title **Selección de parámetros**
# Definición de la función para entrenar el modelo con los nuevos valores de U1 y U2
history = None
model = None
X_test=None
Data_inf = None
Data_T= None
def entrenar_modelo(U1, U2, Pmax, Pmin, Fg_max, Fg_min,path):
    global history
    global model
    global X_test
    global Data_inf
    global Data_T

    lr_reducer = LRReducer(epoch_threshold=[400, 500, 580])
    AJ = 'S'
    s = 1
    if AJ == 'D':
        ajus = [-12.4, -13, -2.8, -1.7, 0, 4, 8, 10, 10]
    elif AJ == 'M':
        ajus = [6.5, 8.7, 10.5, 11.9, 13.1, 14.1, 15, 15.8, 36]
    elif AJ == 'S':
        ajus = [12.4, 13.7, 14.8, 15.7, 16.4, 17.2, 17.8, 18.3, 48]

    # Cargar datos

    nodos = 8
    N = 20000

    if nodos == 18:
        path = path + 'ng_caseCol_' + str(nodos) + '.xlsx'
        ajusts = ajus[-1]
    else:
        path = path + 'ng_case' + str(nodos) + '.xlsx'
        ajusts = ajus[nodos - 8]

    Data_inf = pd.read_excel(path, sheet_name='node.info')
    Data_T = pd.read_excel(path, sheet_name='pipe')

    # Actualizar valores en Data_inf
    Data_inf['Pmax'] = Pmax
    Data_inf['Pmin'] = Pmin

    # Actualizar valores en Data_T
    Data_T['Fg_max'] = Fg_max
    Data_T['Fg_min'] = Fg_min



    N = 20000
    Data_D = pd.read_excel(path, sheet_name='node.dem')
    Data_Dc = pd.read_excel(path, sheet_name='node.demcost')
    Data_W = pd.read_excel(path, sheet_name='well')
    Data_C = pd.read_excel(path, sheet_name='comp')
    Data_sto = pd.read_excel(path, sheet_name='sto')

    Cost = np.concatenate((
        Data_W['Cg'].values,
        Data_T['C_O'].values,
        Data_C['costc'],
        Data_Dc['al_Res'].values,
        Data_Dc['al_Ind'].values,
        Data_Dc['al_Com'].values,
        Data_Dc['al_NGV'].values,
        Data_Dc['al_Ref'].values,
        Data_Dc['al_Pet'].values,
        Data_sto['C_S+'].values - Data_sto['C_V'].values,
        -1 * (Data_sto['C_S-'] - Data_sto['C_V']).values,
        Data_sto['C_V'].values
    )).reshape(-1, 1)

    cost = Cost
    w = GenW(Data_inf, Data_W, Data_T, Data_C, Data_Dc, Data_sto)
    min_value = Data_D.values.sum(axis=1).min()
    max_value = Data_D.values.sum(axis=1).max()

    # Crear el conjunto de datos de entrenamiento
    X_train, X_test = train_test_split(np.random.uniform(min_value, max_value - ajusts, (N, nodos)), shuffle=True, test_size=0.2)
    fd = np.array(X_train).max(axis=0)

    # Crear el modelo con los nuevos valores de U1 y U2
    model = flow_model(path, fd, U1=U1, U2=U2, a=1e-4, b=1e-4, c=1e-4, s=s, G=0)
    history = model.fit(X_train, X_train, epochs=300, validation_split=0.2, verbose=True, batch_size=256, callbacks=[lr_reducer])


# Widgets para cambiar los valores de U1, U2, Pmax, Pmin, Fg_max y Fg_min
U1_widget = widgets.IntSlider(value=256, min=128, max=512, step=32, description='U1:')
U2_widget = widgets.IntSlider(value=2048, min=1024, max=4096, step=256, description='U2:')
Pmax_widget = widgets.FloatSlider(value=1250, min=1000, max=1500, step=10, description='Pmax:')
Pmin_widget = widgets.FloatSlider(value=250, min=0, max=500, step=10, description='Pmin:')
Fg_max_widget = widgets.FloatSlider(value=80, min=0, max=100, step=5, description='Fg_max:')
Fg_min_widget = widgets.FloatSlider(value=-80, min=-100, max=0, step=5, description='Fg_min:')

# Botón para entrenar el modelo con los nuevos valores
button = widgets.Button(description='Entrenar Modelo')

# Función que se ejecuta al presionar el botón
def on_button_clicked(b):
    clear_output(wait=True)
    display(U1_widget, U2_widget, Pmax_widget, Pmin_widget, Fg_max_widget, Fg_min_widget, button)
    U1 = U1_widget.value
    U2 = U2_widget.value
    Pmax = Pmax_widget.value
    Pmin = Pmin_widget.value
    Fg_max = Fg_max_widget.value
    Fg_min = Fg_min_widget.value
    entrenar_modelo(U1, U2, Pmax, Pmin, Fg_max, Fg_min, path)

button.on_click(on_button_clicked)

# Mostrar los widgets y el botón
display(U1_widget, U2_widget, Pmax_widget, Pmin_widget, Fg_max_widget, Fg_min_widget, button)
# Out:
# IntSlider(value=512, description='U1:', max=512, min=128, step=32)
# IntSlider(value=4096, description='U2:', max=4096, min=1024, step=256)
# FloatSlider(value=1500.0, description='Pmax:', max=1500.0, min=1000.0, step=10.0)
# FloatSlider(value=500.0, description='Pmin:', max=500.0, step=10.0)
# FloatSlider(value=100.0, description='Fg_max:', step=5.0)
# FloatSlider(value=-100.0, description='Fg_min:', max=0.0, min=-100.0, step=5.0)
# Button(description='Entrenar Modelo', style=ButtonStyle())
# Epoch 1/300
# 50/50 [==============================] - 10s 20ms/step - loss: 26.3556 - Bal_loss: 23.4537 - Wey_loss: 90.8496 - Ratio_loss: 10.5193 - val_loss: 9.9416 - val_Bal_loss: 10.6433 - val_Wey_loss: 33.6131 - val_Ratio_loss: 0.5138
# Epoch 2/300
# 50/50 [==============================] - 0s 9ms/step - loss: 7.8519 - Bal_loss: 3.3072 - Wey_loss: 54.3097 - Ratio_loss: 1.3260 - val_loss: 8.8824 - val_Bal_loss: 8.2239 - val_Wey_loss: 36.8739 - val_Ratio_loss: 0.7428
# Epoch 3/300
# 50/50 [==============================] - 0s 10ms/step - loss: 6.6952 - Bal_loss: 2.4571 - Wey_loss: 48.8898 - Ratio_loss: 0.9816 - val_loss: 7.2272 - val_Bal_loss: 5.0548 - val_Wey_loss: 38.8069 - val_Ratio_loss: 0.9222
# Epoch 4/300
# 50/50 [==============================] - 0s 9ms/step - loss: 6.1583 - Bal_loss: 2.2292 - Wey_loss: 45.3560 - Ratio_loss: 0.8274 - val_loss: 7.1089 - val_Bal_loss: 4.1194 - val_Wey_loss: 43.3080 - val_Ratio_loss: 0.8992
# Epoch 5/300
# 50/50 [==============================] - 0s 9ms/step - loss: 5.7157 - Bal_loss: 1.7870 - Wey_loss: 43.9221 - Ratio_loss: 0.7158 - val_loss: 7.1277 - val_Bal_loss: 4.0505 - val_Wey_loss: 43.9310 - val_Ratio_loss: 0.8931
# Epoch 6/300
# 50/50 [==============================] - 0s 9ms/step - loss: 5.4733 - Bal_loss: 1.7545 - Wey_loss: 41.8818 - Ratio_loss: 0.6538 - val_loss: 6.1625 - val_Bal_loss: 3.4389 - val_Wey_loss: 38.2454 - val_Ratio_loss: 0.7946
# Epoch 7/300
# 50/50 [==============================] - 0s 9ms/step - loss: 5.1272 - Bal_loss: 1.5468 - Wey_loss: 39.8107 - Ratio_loss: 0.6052 - val_loss: 6.2902 - val_Bal_loss: 3.3686 - val_Wey_loss: 39.8754 - val_Ratio_loss: 0.8164
# Epoch 8/300
# 50/50 [==============================] - 0s 9ms/step - loss: 5.0227 - Bal_loss: 1.5740 - Wey_loss: 38.7530 - Ratio_loss: 0.5550 - val_loss: 6.1313 - val_Bal_loss: 3.1269 - val_Wey_loss: 40.0973 - val_Ratio_loss: 0.6968
# Epoch 9/300
# 50/50 [==============================] - 1s 14ms/step - loss: 4.8010 - Bal_loss: 1.3234 - Wey_loss: 38.2010 - Ratio_loss: 0.5012 - val_loss: 5.6982 - val_Bal_loss: 2.5578 - val_Wey_loss: 39.3473 - val_Ratio_loss: 0.6407
# Epoch 10/300
# 50/50 [==============================] - 1s 12ms/step - loss: 4.5830 - Bal_loss: 1.2494 - Wey_loss: 36.5519 - Ratio_loss: 0.4721 - val_loss: 5.3918 - val_Bal_loss: 2.2865 - val_Wey_loss: 38.1029 - val_Ratio_loss: 0.5773
# Epoch 11/300
# 50/50 [==============================] - 1s 13ms/step - loss: 4.5126 - Bal_loss: 1.2616 - Wey_loss: 35.8451 - Ratio_loss: 0.4481 - val_loss: 4.8919 - val_Bal_loss: 1.6322 - val_Wey_loss: 37.1276 - val_Ratio_loss: 0.5434
# Epoch 12/300
# 50/50 [==============================] - 1s 14ms/step - loss: 4.3132 - Bal_loss: 1.2504 - Wey_loss: 33.9648 - Ratio_loss: 0.4321 - val_loss: 4.6886 - val_Bal_loss: 1.6041 - val_Wey_loss: 35.2910 - val_Ratio_loss: 0.5339
# Epoch 13/300
# 50/50 [==============================] - 1s 12ms/step - loss: 4.0753 - Bal_loss: 1.0561 - Wey_loss: 32.8128 - Ratio_loss: 0.4111 - val_loss: 4.4644 - val_Bal_loss: 1.2858 - val_Wey_loss: 34.9741 - val_Ratio_loss: 0.5280
# Epoch 14/300
# 50/50 [==============================] - 0s 10ms/step - loss: 3.9921 - Bal_loss: 1.0408 - Wey_loss: 32.1113 - Ratio_loss: 0.3971 - val_loss: 4.3653 - val_Bal_loss: 1.5528 - val_Wey_loss: 32.8132 - val_Ratio_loss: 0.3830
# Epoch 15/300
# 50/50 [==============================] - 0s 9ms/step - loss: 3.9367 - Bal_loss: 1.0108 - Wey_loss: 31.7510 - Ratio_loss: 0.3923 - val_loss: 3.9428 - val_Bal_loss: 1.1353 - val_Wey_loss: 30.8353 - val_Ratio_loss: 0.4683
# Epoch 16/300
# 50/50 [==============================] - 0s 10ms/step - loss: 3.6399 - Bal_loss: 0.9455 - Wey_loss: 29.1721 - Ratio_loss: 0.3924 - val_loss: 3.6933 - val_Bal_loss: 1.4789 - val_Wey_loss: 26.6811 - val_Ratio_loss: 0.3337
# Epoch 17/300
# 50/50 [==============================] - 0s 9ms/step - loss: 3.4401 - Bal_loss: 0.9218 - Wey_loss: 27.3088 - Ratio_loss: 0.3941 - val_loss: 3.2601 - val_Bal_loss: 0.9792 - val_Wey_loss: 25.1695 - val_Ratio_loss: 0.3917
# Epoch 18/300
# 50/50 [==============================] - 0s 10ms/step - loss: 3.2680 - Bal_loss: 0.8675 - Wey_loss: 25.9617 - Ratio_loss: 0.3766 - val_loss: 3.0877 - val_Bal_loss: 0.9029 - val_Wey_loss: 23.8622 - val_Ratio_loss: 0.4037
# Epoch 19/300
# 50/50 [==============================] - 1s 10ms/step - loss: 3.0502 - Bal_loss: 0.8993 - Wey_loss: 23.5943 - Ratio_loss: 0.3748 - val_loss: 2.9840 - val_Bal_loss: 1.2979 - val_Wey_loss: 20.6702 - val_Ratio_loss: 0.3309
# Epoch 20/300
# 50/50 [==============================] - 0s 9ms/step - loss: 2.8004 - Bal_loss: 0.8037 - Wey_loss: 21.7725 - Ratio_loss: 0.3389 - val_loss: 2.4890 - val_Bal_loss: 0.7540 - val_Wey_loss: 19.0559 - val_Ratio_loss: 0.3048
# Epoch 21/300
# 50/50 [==============================] - 0s 9ms/step - loss: 2.5503 - Bal_loss: 0.7668 - Wey_loss: 19.5166 - Ratio_loss: 0.3293 - val_loss: 2.3445 - val_Bal_loss: 0.8226 - val_Wey_loss: 17.1192 - val_Ratio_loss: 0.3301
# Epoch 22/300
# 50/50 [==============================] - 0s 10ms/step - loss: 2.2490 - Bal_loss: 0.8206 - Wey_loss: 16.2847 - Ratio_loss: 0.2930 - val_loss: 2.3638 - val_Bal_loss: 0.8819 - val_Wey_loss: 17.0362 - val_Ratio_loss: 0.3016
# Epoch 23/300
# 50/50 [==============================] - 0s 9ms/step - loss: 1.9923 - Bal_loss: 0.7670 - Wey_loss: 14.0740 - Ratio_loss: 0.2800 - val_loss: 2.5318 - val_Bal_loss: 1.3430 - val_Wey_loss: 15.9153 - val_Ratio_loss: 0.3115
# Epoch 24/300
# 50/50 [==============================] - 0s 10ms/step - loss: 1.7513 - Bal_loss: 0.6518 - Wey_loss: 12.4705 - Ratio_loss: 0.2398 - val_loss: 1.9302 - val_Bal_loss: 0.8684 - val_Wey_loss: 12.9601 - val_Ratio_loss: 0.2387
# Epoch 25/300
# 50/50 [==============================] - 0s 9ms/step - loss: 1.5408 - Bal_loss: 0.6678 - Wey_loss: 10.3719 - Ratio_loss: 0.2036 - val_loss: 1.5858 - val_Bal_loss: 0.8549 - val_Wey_loss: 9.7350 - val_Ratio_loss: 0.1910
# Epoch 26/300
# 50/50 [==============================] - 0s 10ms/step - loss: 1.2997 - Bal_loss: 0.6940 - Wey_loss: 7.9019 - Ratio_loss: 0.1695 - val_loss: 1.3598 - val_Bal_loss: 0.7976 - val_Wey_loss: 7.9533 - val_Ratio_loss: 0.1446
# Epoch 27/300
# 50/50 [==============================] - 0s 9ms/step - loss: 1.0288 - Bal_loss: 0.6672 - Wey_loss: 5.4083 - Ratio_loss: 0.1500 - val_loss: 1.1289 - val_Bal_loss: 0.7277 - val_Wey_loss: 6.0768 - val_Ratio_loss: 0.1394
# Epoch 28/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.8858 - Bal_loss: 0.6279 - Wey_loss: 4.2640 - Ratio_loss: 0.1326 - val_loss: 1.1940 - val_Bal_loss: 0.9794 - val_Wey_loss: 5.2381 - val_Ratio_loss: 0.1318
# Epoch 29/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.7489 - Bal_loss: 0.6317 - Wey_loss: 2.8608 - Ratio_loss: 0.1357 - val_loss: 0.8440 - val_Bal_loss: 0.5539 - val_Wey_loss: 4.2960 - val_Ratio_loss: 0.1291
# Epoch 30/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.5534 - Bal_loss: 0.5378 - Wey_loss: 1.4898 - Ratio_loss: 0.1277 - val_loss: 0.8453 - val_Bal_loss: 0.7646 - val_Wey_loss: 3.0468 - val_Ratio_loss: 0.1277
# Epoch 31/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.5269 - Bal_loss: 0.5635 - Wey_loss: 1.0743 - Ratio_loss: 0.1260 - val_loss: 0.7544 - val_Bal_loss: 0.8038 - val_Wey_loss: 1.8970 - val_Ratio_loss: 0.1294
# Epoch 32/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.5007 - Bal_loss: 0.5457 - Wey_loss: 0.9179 - Ratio_loss: 0.1259 - val_loss: 0.5239 - val_Bal_loss: 0.4906 - val_Wey_loss: 1.4717 - val_Ratio_loss: 0.1287
# Epoch 33/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.4986 - Bal_loss: 0.5537 - Wey_loss: 0.8493 - Ratio_loss: 0.1257 - val_loss: 0.7147 - val_Bal_loss: 0.8489 - val_Wey_loss: 1.2319 - val_Ratio_loss: 0.1283
# Epoch 34/300
# 50/50 [==============================] - 1s 12ms/step - loss: 0.4664 - Bal_loss: 0.5051 - Wey_loss: 0.8183 - Ratio_loss: 0.1255 - val_loss: 0.4908 - val_Bal_loss: 0.5171 - val_Wey_loss: 0.9822 - val_Ratio_loss: 0.1277
# Epoch 35/300
# 50/50 [==============================] - 1s 12ms/step - loss: 0.4680 - Bal_loss: 0.5175 - Wey_loss: 0.7595 - Ratio_loss: 0.1255 - val_loss: 1.0707 - val_Bal_loss: 1.4859 - val_Wey_loss: 0.9741 - val_Ratio_loss: 0.1260
# Epoch 36/300
# 50/50 [==============================] - 1s 12ms/step - loss: 0.4781 - Bal_loss: 0.5384 - Wey_loss: 0.7332 - Ratio_loss: 0.1255 - val_loss: 0.6092 - val_Bal_loss: 0.7221 - val_Wey_loss: 0.9422 - val_Ratio_loss: 0.1258
# Epoch 37/300
# 50/50 [==============================] - 1s 14ms/step - loss: 0.4563 - Bal_loss: 0.5006 - Wey_loss: 0.7424 - Ratio_loss: 0.1254 - val_loss: 0.5358 - val_Bal_loss: 0.6144 - val_Wey_loss: 0.8541 - val_Ratio_loss: 0.1254
# Epoch 38/300
# 50/50 [==============================] - 1s 12ms/step - loss: 0.4478 - Bal_loss: 0.4940 - Wey_loss: 0.6968 - Ratio_loss: 0.1253 - val_loss: 0.6131 - val_Bal_loss: 0.7590 - val_Wey_loss: 0.7597 - val_Ratio_loss: 0.1253
# Epoch 39/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.4483 - Bal_loss: 0.5023 - Wey_loss: 0.6520 - Ratio_loss: 0.1254 - val_loss: 0.5174 - val_Bal_loss: 0.5998 - val_Wey_loss: 0.7578 - val_Ratio_loss: 0.1251
# Epoch 40/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.4247 - Bal_loss: 0.4636 - Wey_loss: 0.6475 - Ratio_loss: 0.1251 - val_loss: 0.4135 - val_Bal_loss: 0.4227 - val_Wey_loss: 0.7799 - val_Ratio_loss: 0.1250
# Epoch 41/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.4131 - Bal_loss: 0.4473 - Wey_loss: 0.6284 - Ratio_loss: 0.1250 - val_loss: 0.5202 - val_Bal_loss: 0.5900 - val_Wey_loss: 0.8429 - val_Ratio_loss: 0.1250
# Epoch 42/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.4440 - Bal_loss: 0.4975 - Wey_loss: 0.6358 - Ratio_loss: 0.1250 - val_loss: 0.5178 - val_Bal_loss: 0.6157 - val_Wey_loss: 0.6634 - val_Ratio_loss: 0.1250
# Epoch 43/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.4051 - Bal_loss: 0.4381 - Wey_loss: 0.6012 - Ratio_loss: 0.1249 - val_loss: 0.4757 - val_Bal_loss: 0.5332 - val_Wey_loss: 0.7356 - val_Ratio_loss: 0.1248
# Epoch 44/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.3888 - Bal_loss: 0.4140 - Wey_loss: 0.5824 - Ratio_loss: 0.1248 - val_loss: 0.6149 - val_Bal_loss: 0.7599 - val_Wey_loss: 0.7679 - val_Ratio_loss: 0.1249
# Epoch 45/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.4021 - Bal_loss: 0.4358 - Wey_loss: 0.5833 - Ratio_loss: 0.1247 - val_loss: 0.5929 - val_Bal_loss: 0.7676 - val_Wey_loss: 0.5003 - val_Ratio_loss: 0.1248
# Epoch 46/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.3959 - Bal_loss: 0.4330 - Wey_loss: 0.5385 - Ratio_loss: 0.1246 - val_loss: 0.4956 - val_Bal_loss: 0.5800 - val_Wey_loss: 0.6527 - val_Ratio_loss: 0.1248
# Epoch 47/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.3899 - Bal_loss: 0.4243 - Wey_loss: 0.5301 - Ratio_loss: 0.1247 - val_loss: 0.3979 - val_Bal_loss: 0.4232 - val_Wey_loss: 0.6160 - val_Ratio_loss: 0.1248
# Epoch 48/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.3924 - Bal_loss: 0.4327 - Wey_loss: 0.5050 - Ratio_loss: 0.1244 - val_loss: 0.4363 - val_Bal_loss: 0.4914 - val_Wey_loss: 0.5908 - val_Ratio_loss: 0.1245
# Epoch 49/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.3870 - Bal_loss: 0.4216 - Wey_loss: 0.5160 - Ratio_loss: 0.1241 - val_loss: 0.4291 - val_Bal_loss: 0.4265 - val_Wey_loss: 0.9065 - val_Ratio_loss: 0.1243
# Epoch 50/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.3677 - Bal_loss: 0.3874 - Wey_loss: 0.5278 - Ratio_loss: 0.1240 - val_loss: 0.3322 - val_Bal_loss: 0.3126 - val_Wey_loss: 0.6210 - val_Ratio_loss: 0.1242
# Epoch 51/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.3662 - Bal_loss: 0.3862 - Wey_loss: 0.5214 - Ratio_loss: 0.1236 - val_loss: 0.4066 - val_Bal_loss: 0.4246 - val_Wey_loss: 0.6930 - val_Ratio_loss: 0.1242
# Epoch 52/300
# 50/50 [==============================] - 1s 11ms/step - loss: 0.4034 - Bal_loss: 0.4461 - Wey_loss: 0.5341 - Ratio_loss: 0.1235 - val_loss: 0.4143 - val_Bal_loss: 0.4429 - val_Wey_loss: 0.6610 - val_Ratio_loss: 0.1237
# Epoch 53/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.3937 - Bal_loss: 0.4262 - Wey_loss: 0.5577 - Ratio_loss: 0.1229 - val_loss: 0.4603 - val_Bal_loss: 0.5301 - val_Wey_loss: 0.5974 - val_Ratio_loss: 0.1236
# Epoch 54/300
# 50/50 [==============================] - 1s 11ms/step - loss: 0.3921 - Bal_loss: 0.4273 - Wey_loss: 0.5342 - Ratio_loss: 0.1227 - val_loss: 0.3931 - val_Bal_loss: 0.4329 - val_Wey_loss: 0.5101 - val_Ratio_loss: 0.1228
# Epoch 55/300
# 50/50 [==============================] - 1s 10ms/step - loss: 0.3885 - Bal_loss: 0.4212 - Wey_loss: 0.5366 - Ratio_loss: 0.1222 - val_loss: 0.3849 - val_Bal_loss: 0.3944 - val_Wey_loss: 0.6648 - val_Ratio_loss: 0.1211
# Epoch 56/300
# 50/50 [==============================] - 1s 10ms/step - loss: 0.3568 - Bal_loss: 0.3705 - Wey_loss: 0.5244 - Ratio_loss: 0.1216 - val_loss: 0.3792 - val_Bal_loss: 0.4058 - val_Wey_loss: 0.5349 - val_Ratio_loss: 0.1218
# Epoch 57/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.3612 - Bal_loss: 0.3829 - Wey_loss: 0.4949 - Ratio_loss: 0.1210 - val_loss: 0.3430 - val_Bal_loss: 0.3631 - val_Wey_loss: 0.4313 - val_Ratio_loss: 0.1209
# Epoch 58/300
# 50/50 [==============================] - 1s 10ms/step - loss: 0.3341 - Bal_loss: 0.3419 - Wey_loss: 0.4722 - Ratio_loss: 0.1205 - val_loss: 0.3868 - val_Bal_loss: 0.4314 - val_Wey_loss: 0.4602 - val_Ratio_loss: 0.1209
# Epoch 59/300
# 50/50 [==============================] - 1s 13ms/step - loss: 0.3601 - Bal_loss: 0.3821 - Wey_loss: 0.4938 - Ratio_loss: 0.1197 - val_loss: 0.3225 - val_Bal_loss: 0.2613 - val_Wey_loss: 0.8395 - val_Ratio_loss: 0.1204
# Epoch 60/300
# 50/50 [==============================] - 1s 12ms/step - loss: 0.3744 - Bal_loss: 0.3949 - Wey_loss: 0.5623 - Ratio_loss: 0.1187 - val_loss: 0.3301 - val_Bal_loss: 0.3335 - val_Wey_loss: 0.4882 - val_Ratio_loss: 0.1184
# Epoch 61/300
# 50/50 [==============================] - 1s 15ms/step - loss: 0.3680 - Bal_loss: 0.3951 - Wey_loss: 0.4991 - Ratio_loss: 0.1180 - val_loss: 0.4588 - val_Bal_loss: 0.5469 - val_Wey_loss: 0.4924 - val_Ratio_loss: 0.1194
# Epoch 62/300
# 50/50 [==============================] - 1s 14ms/step - loss: 0.3418 - Bal_loss: 0.3537 - Wey_loss: 0.4875 - Ratio_loss: 0.1173 - val_loss: 0.3340 - val_Bal_loss: 0.3606 - val_Wey_loss: 0.3641 - val_Ratio_loss: 0.1190
# Epoch 63/300
# 50/50 [==============================] - 1s 11ms/step - loss: 0.3356 - Bal_loss: 0.3461 - Wey_loss: 0.4742 - Ratio_loss: 0.1164 - val_loss: 0.3899 - val_Bal_loss: 0.3886 - val_Wey_loss: 0.7601 - val_Ratio_loss: 0.1171
# Epoch 64/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.3264 - Bal_loss: 0.3320 - Wey_loss: 0.4718 - Ratio_loss: 0.1147 - val_loss: 0.3230 - val_Bal_loss: 0.3167 - val_Wey_loss: 0.5309 - val_Ratio_loss: 0.1142
# Epoch 65/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.3729 - Bal_loss: 0.4075 - Wey_loss: 0.4856 - Ratio_loss: 0.1141 - val_loss: 0.4005 - val_Bal_loss: 0.4490 - val_Wey_loss: 0.5134 - val_Ratio_loss: 0.1141
# Epoch 66/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.3435 - Bal_loss: 0.3591 - Wey_loss: 0.4881 - Ratio_loss: 0.1121 - val_loss: 0.2996 - val_Bal_loss: 0.2888 - val_Wey_loss: 0.4822 - val_Ratio_loss: 0.1082
# Epoch 67/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.3336 - Bal_loss: 0.3395 - Wey_loss: 0.5125 - Ratio_loss: 0.1102 - val_loss: 0.4278 - val_Bal_loss: 0.4660 - val_Wey_loss: 0.7085 - val_Ratio_loss: 0.1059
# Epoch 68/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.3493 - Bal_loss: 0.3716 - Wey_loss: 0.4831 - Ratio_loss: 0.1082 - val_loss: 0.4044 - val_Bal_loss: 0.4471 - val_Wey_loss: 0.5902 - val_Ratio_loss: 0.1054
# Epoch 69/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.3571 - Bal_loss: 0.3850 - Wey_loss: 0.4881 - Ratio_loss: 0.1057 - val_loss: 0.3434 - val_Bal_loss: 0.3594 - val_Wey_loss: 0.5100 - val_Ratio_loss: 0.1042
# Epoch 70/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.3268 - Bal_loss: 0.3355 - Wey_loss: 0.4900 - Ratio_loss: 0.1031 - val_loss: 0.5152 - val_Bal_loss: 0.6438 - val_Wey_loss: 0.5279 - val_Ratio_loss: 0.1018
# Epoch 71/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.3120 - Bal_loss: 0.3143 - Wey_loss: 0.4750 - Ratio_loss: 0.1011 - val_loss: 0.3469 - val_Bal_loss: 0.3382 - val_Wey_loss: 0.6880 - val_Ratio_loss: 0.0991
# Epoch 72/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.3522 - Bal_loss: 0.3831 - Wey_loss: 0.4724 - Ratio_loss: 0.0988 - val_loss: 0.3537 - val_Bal_loss: 0.3882 - val_Wey_loss: 0.4486 - val_Ratio_loss: 0.1018
# Epoch 73/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.3215 - Bal_loss: 0.3333 - Wey_loss: 0.4724 - Ratio_loss: 0.0962 - val_loss: 0.2957 - val_Bal_loss: 0.2835 - val_Wey_loss: 0.5011 - val_Ratio_loss: 0.1004
# Epoch 74/300
# 50/50 [==============================] - 1s 10ms/step - loss: 0.3093 - Bal_loss: 0.3170 - Wey_loss: 0.4563 - Ratio_loss: 0.0939 - val_loss: 0.4702 - val_Bal_loss: 0.5806 - val_Wey_loss: 0.4832 - val_Ratio_loss: 0.0942
# Epoch 75/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.3400 - Bal_loss: 0.3677 - Wey_loss: 0.4669 - Ratio_loss: 0.0913 - val_loss: 0.2787 - val_Bal_loss: 0.2717 - val_Wey_loss: 0.4509 - val_Ratio_loss: 0.0845
# Epoch 76/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.3407 - Bal_loss: 0.3625 - Wey_loss: 0.5167 - Ratio_loss: 0.0879 - val_loss: 0.2785 - val_Bal_loss: 0.2117 - val_Wey_loss: 0.8224 - val_Ratio_loss: 0.0802
# Epoch 77/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.3085 - Bal_loss: 0.3225 - Wey_loss: 0.4443 - Ratio_loss: 0.0848 - val_loss: 0.2602 - val_Bal_loss: 0.2604 - val_Wey_loss: 0.3379 - val_Ratio_loss: 0.0837
# Epoch 78/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.3084 - Bal_loss: 0.3234 - Wey_loss: 0.4447 - Ratio_loss: 0.0828 - val_loss: 0.3060 - val_Bal_loss: 0.3033 - val_Wey_loss: 0.5401 - val_Ratio_loss: 0.0833
# Epoch 79/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.3407 - Bal_loss: 0.3700 - Wey_loss: 0.4960 - Ratio_loss: 0.0805 - val_loss: 0.2967 - val_Bal_loss: 0.2852 - val_Wey_loss: 0.5632 - val_Ratio_loss: 0.0812
# Epoch 80/300
# 50/50 [==============================] - 1s 10ms/step - loss: 0.2986 - Bal_loss: 0.3118 - Wey_loss: 0.4342 - Ratio_loss: 0.0770 - val_loss: 0.3321 - val_Bal_loss: 0.3568 - val_Wey_loss: 0.4847 - val_Ratio_loss: 0.0824
# Epoch 81/300
# 50/50 [==============================] - 1s 10ms/step - loss: 0.2980 - Bal_loss: 0.3174 - Wey_loss: 0.4054 - Ratio_loss: 0.0739 - val_loss: 0.3395 - val_Bal_loss: 0.3738 - val_Wey_loss: 0.4726 - val_Ratio_loss: 0.0774
# Epoch 82/300
# 50/50 [==============================] - 1s 10ms/step - loss: 0.3231 - Bal_loss: 0.3542 - Wey_loss: 0.4449 - Ratio_loss: 0.0714 - val_loss: 0.2718 - val_Bal_loss: 0.2536 - val_Wey_loss: 0.5216 - val_Ratio_loss: 0.0761
# Epoch 83/300
# 50/50 [==============================] - 1s 10ms/step - loss: 0.3047 - Bal_loss: 0.3309 - Wey_loss: 0.4077 - Ratio_loss: 0.0691 - val_loss: 0.5432 - val_Bal_loss: 0.6721 - val_Wey_loss: 0.7739 - val_Ratio_loss: 0.0599
# Epoch 84/300
# 50/50 [==============================] - 1s 14ms/step - loss: 0.2911 - Bal_loss: 0.3047 - Wey_loss: 0.4404 - Ratio_loss: 0.0657 - val_loss: 0.3121 - val_Bal_loss: 0.3279 - val_Wey_loss: 0.5486 - val_Ratio_loss: 0.0533
# Epoch 85/300
# 50/50 [==============================] - 1s 12ms/step - loss: 0.2843 - Bal_loss: 0.2986 - Wey_loss: 0.4189 - Ratio_loss: 0.0627 - val_loss: 0.2810 - val_Bal_loss: 0.3060 - val_Wey_loss: 0.3627 - val_Ratio_loss: 0.0557
# Epoch 86/300
# 50/50 [==============================] - 1s 13ms/step - loss: 0.2829 - Bal_loss: 0.3030 - Wey_loss: 0.3892 - Ratio_loss: 0.0595 - val_loss: 0.3941 - val_Bal_loss: 0.4484 - val_Wey_loss: 0.6500 - val_Ratio_loss: 0.0531
# Epoch 87/300
# 50/50 [==============================] - 1s 14ms/step - loss: 0.2916 - Bal_loss: 0.3074 - Wey_loss: 0.4616 - Ratio_loss: 0.0565 - val_loss: 0.2844 - val_Bal_loss: 0.3100 - val_Wey_loss: 0.3823 - val_Ratio_loss: 0.0539
# Epoch 88/300
# 50/50 [==============================] - 1s 13ms/step - loss: 0.2672 - Bal_loss: 0.2845 - Wey_loss: 0.3638 - Ratio_loss: 0.0542 - val_loss: 0.4009 - val_Bal_loss: 0.4595 - val_Wey_loss: 0.6572 - val_Ratio_loss: 0.0523
# Epoch 89/300
# 50/50 [==============================] - 1s 11ms/step - loss: 0.2719 - Bal_loss: 0.2918 - Wey_loss: 0.3773 - Ratio_loss: 0.0514 - val_loss: 0.4950 - val_Bal_loss: 0.5931 - val_Wey_loss: 0.7802 - val_Ratio_loss: 0.0581
# Epoch 90/300
# 50/50 [==============================] - 0s 8ms/step - loss: 0.3082 - Bal_loss: 0.3416 - Wey_loss: 0.4476 - Ratio_loss: 0.0495 - val_loss: 0.4372 - val_Bal_loss: 0.5143 - val_Wey_loss: 0.7043 - val_Ratio_loss: 0.0487
# Epoch 91/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.2904 - Bal_loss: 0.3187 - Wey_loss: 0.4194 - Ratio_loss: 0.0460 - val_loss: 0.4992 - val_Bal_loss: 0.5659 - val_Wey_loss: 1.0318 - val_Ratio_loss: 0.0437
# Epoch 92/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.2640 - Bal_loss: 0.2811 - Wey_loss: 0.3933 - Ratio_loss: 0.0424 - val_loss: 0.2591 - val_Bal_loss: 0.2605 - val_Wey_loss: 0.4912 - val_Ratio_loss: 0.0349
# Epoch 93/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.2826 - Bal_loss: 0.3168 - Wey_loss: 0.3731 - Ratio_loss: 0.0405 - val_loss: 0.2878 - val_Bal_loss: 0.3414 - val_Wey_loss: 0.2969 - val_Ratio_loss: 0.0342
# Epoch 94/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.2818 - Bal_loss: 0.3183 - Wey_loss: 0.3647 - Ratio_loss: 0.0378 - val_loss: 0.3027 - val_Bal_loss: 0.3312 - val_Wey_loss: 0.5077 - val_Ratio_loss: 0.0345
# Epoch 95/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.2900 - Bal_loss: 0.3266 - Wey_loss: 0.4073 - Ratio_loss: 0.0351 - val_loss: 0.3334 - val_Bal_loss: 0.4011 - val_Wey_loss: 0.4192 - val_Ratio_loss: 0.0269
# Epoch 96/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.2777 - Bal_loss: 0.3125 - Wey_loss: 0.3799 - Ratio_loss: 0.0318 - val_loss: 0.2611 - val_Bal_loss: 0.2799 - val_Wey_loss: 0.4240 - val_Ratio_loss: 0.0273
# Epoch 97/300
# 50/50 [==============================] - 1s 20ms/step - loss: 0.2476 - Bal_loss: 0.2687 - Wey_loss: 0.3516 - Ratio_loss: 0.0293 - val_loss: 0.2198 - val_Bal_loss: 0.2096 - val_Wey_loss: 0.4234 - val_Ratio_loss: 0.0313
# Epoch 98/300
# 50/50 [==============================] - 1s 15ms/step - loss: 0.2728 - Bal_loss: 0.3087 - Wey_loss: 0.3703 - Ratio_loss: 0.0275 - val_loss: 0.3058 - val_Bal_loss: 0.3421 - val_Wey_loss: 0.5016 - val_Ratio_loss: 0.0275
# Epoch 99/300
# 50/50 [==============================] - 1s 19ms/step - loss: 0.2629 - Bal_loss: 0.3033 - Wey_loss: 0.3107 - Ratio_loss: 0.0260 - val_loss: 0.2732 - val_Bal_loss: 0.2944 - val_Wey_loss: 0.4784 - val_Ratio_loss: 0.0228
# Epoch 100/300
# 50/50 [==============================] - 1s 15ms/step - loss: 0.2477 - Bal_loss: 0.2701 - Wey_loss: 0.3656 - Ratio_loss: 0.0243 - val_loss: 0.1595 - val_Bal_loss: 0.1378 - val_Wey_loss: 0.2814 - val_Ratio_loss: 0.0238
# Epoch 101/300
# 50/50 [==============================] - 1s 17ms/step - loss: 0.2615 - Bal_loss: 0.2976 - Wey_loss: 0.3467 - Ratio_loss: 0.0225 - val_loss: 0.2648 - val_Bal_loss: 0.2887 - val_Wey_loss: 0.4407 - val_Ratio_loss: 0.0206
# Epoch 102/300
# 50/50 [==============================] - 1s 17ms/step - loss: 0.2418 - Bal_loss: 0.2683 - Wey_loss: 0.3337 - Ratio_loss: 0.0210 - val_loss: 0.2306 - val_Bal_loss: 0.2364 - val_Wey_loss: 0.4135 - val_Ratio_loss: 0.0208
# Epoch 103/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.2558 - Bal_loss: 0.2925 - Wey_loss: 0.3368 - Ratio_loss: 0.0187 - val_loss: 0.3111 - val_Bal_loss: 0.3733 - val_Wey_loss: 0.3972 - val_Ratio_loss: 0.0224
# Epoch 104/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.2581 - Bal_loss: 0.2987 - Wey_loss: 0.3312 - Ratio_loss: 0.0169 - val_loss: 0.4596 - val_Bal_loss: 0.6015 - val_Wey_loss: 0.5326 - val_Ratio_loss: 0.0163
# Epoch 105/300
# 50/50 [==============================] - 1s 10ms/step - loss: 0.2378 - Bal_loss: 0.2658 - Wey_loss: 0.3331 - Ratio_loss: 0.0155 - val_loss: 0.1947 - val_Bal_loss: 0.2053 - val_Wey_loss: 0.2615 - val_Ratio_loss: 0.0172
# Epoch 106/300
# 50/50 [==============================] - 1s 12ms/step - loss: 0.2300 - Bal_loss: 0.2541 - Wey_loss: 0.3325 - Ratio_loss: 0.0138 - val_loss: 0.2128 - val_Bal_loss: 0.1992 - val_Wey_loss: 0.4952 - val_Ratio_loss: 0.0129
# Epoch 107/300
# 50/50 [==============================] - 1s 12ms/step - loss: 0.2231 - Bal_loss: 0.2504 - Wey_loss: 0.2953 - Ratio_loss: 0.0119 - val_loss: 0.1931 - val_Bal_loss: 0.1885 - val_Wey_loss: 0.3732 - val_Ratio_loss: 0.0102
# Epoch 108/300
# 50/50 [==============================] - 1s 14ms/step - loss: 0.2640 - Bal_loss: 0.3128 - Wey_loss: 0.3388 - Ratio_loss: 0.0098 - val_loss: 0.3522 - val_Bal_loss: 0.4467 - val_Wey_loss: 0.4212 - val_Ratio_loss: 0.0088
# Epoch 109/300
# 50/50 [==============================] - 1s 13ms/step - loss: 0.2267 - Bal_loss: 0.2595 - Wey_loss: 0.2934 - Ratio_loss: 0.0084 - val_loss: 0.2411 - val_Bal_loss: 0.2798 - val_Wey_loss: 0.3289 - val_Ratio_loss: 0.0043
# Epoch 110/300
# 50/50 [==============================] - 1s 13ms/step - loss: 0.2226 - Bal_loss: 0.2529 - Wey_loss: 0.2982 - Ratio_loss: 0.0073 - val_loss: 0.2039 - val_Bal_loss: 0.2345 - val_Wey_loss: 0.2345 - val_Ratio_loss: 0.0035
# Epoch 111/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.2474 - Bal_loss: 0.2955 - Wey_loss: 0.2963 - Ratio_loss: 0.0063 - val_loss: 0.2840 - val_Bal_loss: 0.3445 - val_Wey_loss: 0.3779 - val_Ratio_loss: 0.0036
# Epoch 112/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.2124 - Bal_loss: 0.2452 - Wey_loss: 0.2547 - Ratio_loss: 0.0053 - val_loss: 0.2401 - val_Bal_loss: 0.2571 - val_Wey_loss: 0.4716 - val_Ratio_loss: 0.0024
# Epoch 113/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.2220 - Bal_loss: 0.2606 - Wey_loss: 0.2664 - Ratio_loss: 0.0040 - val_loss: 0.1889 - val_Bal_loss: 0.1956 - val_Wey_loss: 0.3315 - val_Ratio_loss: 0.0024
# Epoch 114/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.2227 - Bal_loss: 0.2565 - Wey_loss: 0.3042 - Ratio_loss: 0.0033 - val_loss: 0.2584 - val_Bal_loss: 0.3056 - val_Wey_loss: 0.3704 - val_Ratio_loss: 0.0025
# Epoch 115/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.2284 - Bal_loss: 0.2627 - Wey_loss: 0.3281 - Ratio_loss: 0.0025 - val_loss: 0.1790 - val_Bal_loss: 0.1798 - val_Wey_loss: 0.3347 - val_Ratio_loss: 0.0015
# Epoch 116/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.2046 - Bal_loss: 0.2320 - Wey_loss: 0.2796 - Ratio_loss: 0.0016 - val_loss: 0.1580 - val_Bal_loss: 0.1441 - val_Wey_loss: 0.3463 - val_Ratio_loss: 7.8182e-04
# Epoch 117/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.2252 - Bal_loss: 0.2675 - Wey_loss: 0.2763 - Ratio_loss: 0.0019 - val_loss: 0.2136 - val_Bal_loss: 0.2425 - val_Wey_loss: 0.3134 - val_Ratio_loss: 0.0011
# Epoch 118/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.2063 - Bal_loss: 0.2371 - Wey_loss: 0.2736 - Ratio_loss: 0.0011 - val_loss: 0.1392 - val_Bal_loss: 0.1339 - val_Wey_loss: 0.2226 - val_Ratio_loss: 0.0013
# Epoch 119/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.2331 - Bal_loss: 0.2794 - Wey_loss: 0.2902 - Ratio_loss: 0.0010 - val_loss: 0.2097 - val_Bal_loss: 0.2151 - val_Wey_loss: 0.4373 - val_Ratio_loss: 0.0031
# Epoch 120/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.2234 - Bal_loss: 0.2624 - Wey_loss: 0.2987 - Ratio_loss: 0.0012 - val_loss: 0.2780 - val_Bal_loss: 0.3048 - val_Wey_loss: 0.5929 - val_Ratio_loss: 8.2090e-04
# Epoch 121/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.2185 - Bal_loss: 0.2569 - Wey_loss: 0.2852 - Ratio_loss: 0.0011 - val_loss: 0.1661 - val_Bal_loss: 0.1664 - val_Wey_loss: 0.3066 - val_Ratio_loss: 6.2535e-04
# Epoch 122/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.2298 - Bal_loss: 0.2856 - Wey_loss: 0.2295 - Ratio_loss: 8.1136e-04 - val_loss: 0.2850 - val_Bal_loss: 0.3191 - val_Wey_loss: 0.5829 - val_Ratio_loss: 5.4735e-04
# Epoch 123/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.2311 - Bal_loss: 0.2826 - Wey_loss: 0.2651 - Ratio_loss: 6.0628e-04 - val_loss: 0.1536 - val_Bal_loss: 0.1378 - val_Wey_loss: 0.3615 - val_Ratio_loss: 3.5193e-04
# Epoch 124/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.2184 - Bal_loss: 0.2627 - Wey_loss: 0.2622 - Ratio_loss: 3.3240e-04 - val_loss: 0.2078 - val_Bal_loss: 0.2078 - val_Wey_loss: 0.4855 - val_Ratio_loss: 5.8648e-04
# Epoch 125/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1832 - Bal_loss: 0.2125 - Wey_loss: 0.2144 - Ratio_loss: 3.7147e-04 - val_loss: 0.1770 - val_Bal_loss: 0.1911 - val_Wey_loss: 0.2850 - val_Ratio_loss: 2.3465e-04
# Epoch 126/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1825 - Bal_loss: 0.2108 - Wey_loss: 0.2233 - Ratio_loss: 4.5953e-04 - val_loss: 0.1641 - val_Bal_loss: 0.1709 - val_Wey_loss: 0.2811 - val_Ratio_loss: 4.6929e-04
# Epoch 127/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.2124 - Bal_loss: 0.2524 - Wey_loss: 0.2761 - Ratio_loss: 5.5736e-04 - val_loss: 0.1876 - val_Bal_loss: 0.2034 - val_Wey_loss: 0.3213 - val_Ratio_loss: 8.6033e-04
# Epoch 128/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.2336 - Bal_loss: 0.2873 - Wey_loss: 0.2796 - Ratio_loss: 8.8985e-04 - val_loss: 0.3041 - val_Bal_loss: 0.4166 - val_Wey_loss: 0.2111 - val_Ratio_loss: 6.2571e-04
# Epoch 129/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.2067 - Bal_loss: 0.2536 - Wey_loss: 0.2168 - Ratio_loss: 7.4353e-04 - val_loss: 0.1594 - val_Bal_loss: 0.1844 - val_Wey_loss: 0.1604 - val_Ratio_loss: 4.3036e-04
# Epoch 130/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1960 - Bal_loss: 0.2365 - Wey_loss: 0.2163 - Ratio_loss: 4.3036e-04 - val_loss: 0.2184 - val_Bal_loss: 0.2320 - val_Wey_loss: 0.4678 - val_Ratio_loss: 6.2586e-04
# Epoch 131/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.2058 - Bal_loss: 0.2465 - Wey_loss: 0.2550 - Ratio_loss: 0.0011 - val_loss: 0.2154 - val_Bal_loss: 0.2300 - val_Wey_loss: 0.4534 - val_Ratio_loss: 3.5217e-04
# Epoch 132/300
# 50/50 [==============================] - 1s 12ms/step - loss: 0.1872 - Bal_loss: 0.2252 - Wey_loss: 0.1994 - Ratio_loss: 0.0014 - val_loss: 0.3312 - val_Bal_loss: 0.4524 - val_Wey_loss: 0.2793 - val_Ratio_loss: 0.0014
# Epoch 133/300
# 50/50 [==============================] - 1s 12ms/step - loss: 0.1993 - Bal_loss: 0.2441 - Wey_loss: 0.2120 - Ratio_loss: 0.0013 - val_loss: 0.3702 - val_Bal_loss: 0.5205 - val_Wey_loss: 0.2574 - val_Ratio_loss: 0.0031
# Epoch 134/300
# 50/50 [==============================] - 1s 14ms/step - loss: 0.2277 - Bal_loss: 0.2853 - Wey_loss: 0.2492 - Ratio_loss: 0.0012 - val_loss: 0.3903 - val_Bal_loss: 0.5544 - val_Wey_loss: 0.2540 - val_Ratio_loss: 0.0033
# Epoch 135/300
# 50/50 [==============================] - 1s 15ms/step - loss: 0.2264 - Bal_loss: 0.2883 - Wey_loss: 0.2213 - Ratio_loss: 9.7855e-04 - val_loss: 0.2628 - val_Bal_loss: 0.2730 - val_Wey_loss: 0.6799 - val_Ratio_loss: 1.1752e-04
# Epoch 136/300
# 50/50 [==============================] - 1s 10ms/step - loss: 0.2237 - Bal_loss: 0.2807 - Wey_loss: 0.2414 - Ratio_loss: 9.7853e-04 - val_loss: 0.3282 - val_Bal_loss: 0.4638 - val_Wey_loss: 0.1908 - val_Ratio_loss: 4.3033e-04
# Epoch 137/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1796 - Bal_loss: 0.2115 - Wey_loss: 0.2186 - Ratio_loss: 7.2400e-04 - val_loss: 0.1711 - val_Bal_loss: 0.2008 - val_Wey_loss: 0.2009 - val_Ratio_loss: 3.5215e-04
# Epoch 138/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1957 - Bal_loss: 0.2414 - Wey_loss: 0.2051 - Ratio_loss: 4.7922e-04 - val_loss: 0.2098 - val_Bal_loss: 0.2630 - val_Wey_loss: 0.2179 - val_Ratio_loss: 3.9128e-04
# Epoch 139/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1940 - Bal_loss: 0.2369 - Wey_loss: 0.2185 - Ratio_loss: 3.5193e-04 - val_loss: 0.2682 - val_Bal_loss: 0.3610 - val_Wey_loss: 0.2174 - val_Ratio_loss: 1.9577e-04
# Epoch 140/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1982 - Bal_loss: 0.2454 - Wey_loss: 0.2130 - Ratio_loss: 2.8343e-04 - val_loss: 0.2020 - val_Bal_loss: 0.2460 - val_Wey_loss: 0.2477 - val_Ratio_loss: 5.8733e-04
# Epoch 141/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1874 - Bal_loss: 0.2318 - Wey_loss: 0.1880 - Ratio_loss: 3.5197e-04 - val_loss: 0.1199 - val_Bal_loss: 0.1157 - val_Wey_loss: 0.2083 - val_Ratio_loss: 9.3981e-04
# Epoch 142/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1671 - Bal_loss: 0.1993 - Wey_loss: 0.1824 - Ratio_loss: 3.9118e-04 - val_loss: 0.1519 - val_Bal_loss: 0.1715 - val_Wey_loss: 0.1987 - val_Ratio_loss: 3.5277e-04
# Epoch 143/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.2091 - Bal_loss: 0.2629 - Wey_loss: 0.2203 - Ratio_loss: 0.0011 - val_loss: 0.2969 - val_Bal_loss: 0.4031 - val_Wey_loss: 0.2584 - val_Ratio_loss: 4.6997e-04
# Epoch 144/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1992 - Bal_loss: 0.2475 - Wey_loss: 0.2136 - Ratio_loss: 0.0013 - val_loss: 0.2474 - val_Bal_loss: 0.3272 - val_Wey_loss: 0.2204 - val_Ratio_loss: 3.1320e-04
# Epoch 145/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1596 - Bal_loss: 0.1851 - Wey_loss: 0.1937 - Ratio_loss: 0.0012 - val_loss: 0.1547 - val_Bal_loss: 0.1778 - val_Wey_loss: 0.1940 - val_Ratio_loss: 2.7397e-04
# Epoch 146/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.2068 - Bal_loss: 0.2634 - Wey_loss: 0.2004 - Ratio_loss: 8.2143e-04 - val_loss: 0.2358 - val_Bal_loss: 0.2571 - val_Wey_loss: 0.5293 - val_Ratio_loss: 7.0453e-04
# Epoch 147/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.2022 - Bal_loss: 0.2557 - Wey_loss: 0.2031 - Ratio_loss: 9.4870e-04 - val_loss: 0.2324 - val_Bal_loss: 0.2572 - val_Wey_loss: 0.4994 - val_Ratio_loss: 3.1325e-04
# Epoch 148/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.1747 - Bal_loss: 0.2119 - Wey_loss: 0.1952 - Ratio_loss: 4.9879e-04 - val_loss: 0.1252 - val_Bal_loss: 0.1325 - val_Wey_loss: 0.1793 - val_Ratio_loss: 2.3479e-04
# Epoch 149/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.2080 - Bal_loss: 0.2684 - Wey_loss: 0.1909 - Ratio_loss: 4.0090e-04 - val_loss: 0.2845 - val_Bal_loss: 0.3632 - val_Wey_loss: 0.3831 - val_Ratio_loss: 0.0018
# Epoch 150/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.2000 - Bal_loss: 0.2517 - Wey_loss: 0.2107 - Ratio_loss: 7.4327e-04 - val_loss: 0.1834 - val_Bal_loss: 0.1772 - val_Wey_loss: 0.4949 - val_Ratio_loss: 3.5217e-04
# Epoch 151/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.2036 - Bal_loss: 0.2547 - Wey_loss: 0.2299 - Ratio_loss: 0.0013 - val_loss: 0.1304 - val_Bal_loss: 0.1285 - val_Wey_loss: 0.2584 - val_Ratio_loss: 4.6977e-04
# Epoch 152/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.1946 - Bal_loss: 0.2480 - Wey_loss: 0.1840 - Ratio_loss: 9.4852e-04 - val_loss: 0.2073 - val_Bal_loss: 0.2551 - val_Wey_loss: 0.2733 - val_Ratio_loss: 7.8364e-05
# Epoch 153/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1653 - Bal_loss: 0.2028 - Wey_loss: 0.1680 - Ratio_loss: 2.9321e-04 - val_loss: 0.1524 - val_Bal_loss: 0.1768 - val_Wey_loss: 0.1977 - val_Ratio_loss: 3.1304e-04
# Epoch 154/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1466 - Bal_loss: 0.1760 - Wey_loss: 0.1464 - Ratio_loss: 2.8350e-04 - val_loss: 0.1530 - val_Bal_loss: 0.1820 - val_Wey_loss: 0.1737 - val_Ratio_loss: 6.2616e-04
# Epoch 155/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1769 - Bal_loss: 0.2246 - Wey_loss: 0.1585 - Ratio_loss: 2.1508e-04 - val_loss: 0.3385 - val_Bal_loss: 0.4771 - val_Wey_loss: 0.2594 - val_Ratio_loss: 9.0001e-04
# Epoch 156/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1631 - Bal_loss: 0.1996 - Wey_loss: 0.1732 - Ratio_loss: 1.0748e-04 - val_loss: 0.1697 - val_Bal_loss: 0.2161 - val_Wey_loss: 0.1393 - val_Ratio_loss: 2.7395e-04
# Epoch 157/300
# 50/50 [==============================] - 1s 10ms/step - loss: 0.1543 - Bal_loss: 0.1875 - Wey_loss: 0.1594 - Ratio_loss: 1.0754e-04 - val_loss: 0.2269 - val_Bal_loss: 0.2836 - val_Wey_loss: 0.3092 - val_Ratio_loss: 1.1742e-04
# Epoch 158/300
# 50/50 [==============================] - 1s 12ms/step - loss: 0.1879 - Bal_loss: 0.2436 - Wey_loss: 0.1607 - Ratio_loss: 9.7735e-05 - val_loss: 0.2649 - val_Bal_loss: 0.3559 - val_Wey_loss: 0.2564 - val_Ratio_loss: 1.9569e-04
# Epoch 159/300
# 50/50 [==============================] - 1s 12ms/step - loss: 0.1974 - Bal_loss: 0.2596 - Wey_loss: 0.1582 - Ratio_loss: 1.0752e-04 - val_loss: 0.1743 - val_Bal_loss: 0.1843 - val_Wey_loss: 0.3802 - val_Ratio_loss: 1.1740e-04
# Epoch 160/300
# 50/50 [==============================] - 1s 13ms/step - loss: 0.2210 - Bal_loss: 0.2891 - Wey_loss: 0.2176 - Ratio_loss: 6.8433e-05 - val_loss: 0.1867 - val_Bal_loss: 0.2167 - val_Wey_loss: 0.3077 - val_Ratio_loss: 3.9092e-05
# Epoch 161/300
# 50/50 [==============================] - 1s 13ms/step - loss: 0.2101 - Bal_loss: 0.2707 - Wey_loss: 0.2199 - Ratio_loss: 1.0753e-04 - val_loss: 0.1676 - val_Bal_loss: 0.1833 - val_Wey_loss: 0.3222 - val_Ratio_loss: 1.1738e-04
# Epoch 162/300
# 50/50 [==============================] - 1s 12ms/step - loss: 0.1831 - Bal_loss: 0.2319 - Wey_loss: 0.1858 - Ratio_loss: 1.5636e-04 - val_loss: 0.1028 - val_Bal_loss: 0.0786 - val_Wey_loss: 0.3030 - val_Ratio_loss: 2.3477e-04
# Epoch 163/300
# 50/50 [==============================] - 1s 10ms/step - loss: 0.1759 - Bal_loss: 0.2226 - Wey_loss: 0.1721 - Ratio_loss: 1.0755e-04 - val_loss: 0.1779 - val_Bal_loss: 0.2026 - val_Wey_loss: 0.3142 - val_Ratio_loss: 1.5650e-04
# Epoch 164/300
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1721 - Bal_loss: 0.2212 - Wey_loss: 0.1451 - Ratio_loss: 1.4662e-04 - val_loss: 0.1670 - val_Bal_loss: 0.2098 - val_Wey_loss: 0.1628 - val_Ratio_loss: 1.5646e-04
# Epoch 165/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1664 - Bal_loss: 0.2070 - Wey_loss: 0.1738 - Ratio_loss: 1.8580e-04 - val_loss: 0.1280 - val_Bal_loss: 0.1410 - val_Wey_loss: 0.1868 - val_Ratio_loss: 2.7402e-04
# Epoch 166/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1730 - Bal_loss: 0.2136 - Wey_loss: 0.2029 - Ratio_loss: 1.8579e-04 - val_loss: 0.0998 - val_Bal_loss: 0.1027 - val_Wey_loss: 0.1362 - val_Ratio_loss: 1.5642e-04
# Epoch 167/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.1588 - Bal_loss: 0.1958 - Wey_loss: 0.1669 - Ratio_loss: 1.8581e-04 - val_loss: 0.1948 - val_Bal_loss: 0.2439 - val_Wey_loss: 0.2391 - val_Ratio_loss: 2.3485e-04
# Epoch 168/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.1673 - Bal_loss: 0.2097 - Wey_loss: 0.1707 - Ratio_loss: 1.3689e-04 - val_loss: 0.1873 - val_Bal_loss: 0.2323 - val_Wey_loss: 0.2365 - val_Ratio_loss: 1.5640e-04
# Epoch 169/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1586 - Bal_loss: 0.1995 - Wey_loss: 0.1484 - Ratio_loss: 1.7598e-04 - val_loss: 0.1313 - val_Bal_loss: 0.1433 - val_Wey_loss: 0.2129 - val_Ratio_loss: 1.1735e-04
# Epoch 170/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1811 - Bal_loss: 0.2355 - Wey_loss: 0.1574 - Ratio_loss: 2.4439e-04 - val_loss: 0.1478 - val_Bal_loss: 0.1672 - val_Wey_loss: 0.2352 - val_Ratio_loss: 1.9563e-04
# Epoch 171/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1703 - Bal_loss: 0.2188 - Wey_loss: 0.1488 - Ratio_loss: 3.6178e-04 - val_loss: 0.2468 - val_Bal_loss: 0.3321 - val_Wey_loss: 0.2345 - val_Ratio_loss: 3.5217e-04
# Epoch 172/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.1677 - Bal_loss: 0.2136 - Wey_loss: 0.1551 - Ratio_loss: 2.1507e-04 - val_loss: 0.2603 - val_Bal_loss: 0.3450 - val_Wey_loss: 0.2922 - val_Ratio_loss: 2.3473e-04
# Epoch 173/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1685 - Bal_loss: 0.2147 - Wey_loss: 0.1596 - Ratio_loss: 2.1507e-04 - val_loss: 0.1075 - val_Bal_loss: 0.1169 - val_Wey_loss: 0.1378 - val_Ratio_loss: 1.1736e-04
# Epoch 174/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1646 - Bal_loss: 0.2099 - Wey_loss: 0.1534 - Ratio_loss: 1.7593e-04 - val_loss: 0.1397 - val_Bal_loss: 0.1507 - val_Wey_loss: 0.2603 - val_Ratio_loss: 1.5647e-04
# Epoch 175/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1836 - Bal_loss: 0.2357 - Wey_loss: 0.1900 - Ratio_loss: 1.7593e-04 - val_loss: 0.1540 - val_Bal_loss: 0.1901 - val_Wey_loss: 0.1682 - val_Ratio_loss: 1.1738e-04
# Epoch 176/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.1712 - Bal_loss: 0.2181 - Wey_loss: 0.1725 - Ratio_loss: 2.9325e-04 - val_loss: 0.1310 - val_Bal_loss: 0.1371 - val_Wey_loss: 0.2571 - val_Ratio_loss: 1.9565e-04
# Epoch 177/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1534 - Bal_loss: 0.1879 - Wey_loss: 0.1775 - Ratio_loss: 3.4214e-04 - val_loss: 0.1762 - val_Bal_loss: 0.2230 - val_Wey_loss: 0.1951 - val_Ratio_loss: 1.1735e-04
# Epoch 178/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.1893 - Bal_loss: 0.2503 - Wey_loss: 0.1633 - Ratio_loss: 3.0299e-04 - val_loss: 0.2630 - val_Bal_loss: 0.3557 - val_Wey_loss: 0.2696 - val_Ratio_loss: 1.1731e-04
# Epoch 179/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1671 - Bal_loss: 0.2171 - Wey_loss: 0.1446 - Ratio_loss: 1.8571e-04 - val_loss: 0.1165 - val_Bal_loss: 0.1089 - val_Wey_loss: 0.2896 - val_Ratio_loss: 2.3461e-04
# Epoch 180/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1704 - Bal_loss: 0.2199 - Wey_loss: 0.1639 - Ratio_loss: 1.6614e-04 - val_loss: 0.1836 - val_Bal_loss: 0.2162 - val_Wey_loss: 0.3184 - val_Ratio_loss: 2.3472e-04
# Epoch 181/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1798 - Bal_loss: 0.2353 - Wey_loss: 0.1669 - Ratio_loss: 1.1725e-04 - val_loss: 0.1381 - val_Bal_loss: 0.1612 - val_Wey_loss: 0.1945 - val_Ratio_loss: 1.1736e-04
# Epoch 182/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1480 - Bal_loss: 0.1855 - Wey_loss: 0.1484 - Ratio_loss: 1.4658e-04 - val_loss: 0.1015 - val_Bal_loss: 0.1042 - val_Wey_loss: 0.1727 - val_Ratio_loss: 1.1734e-04
# Epoch 183/300
# 50/50 [==============================] - 1s 14ms/step - loss: 0.1781 - Bal_loss: 0.2311 - Wey_loss: 0.1770 - Ratio_loss: 1.5633e-04 - val_loss: 0.1855 - val_Bal_loss: 0.2330 - val_Wey_loss: 0.2379 - val_Ratio_loss: 2.3468e-04
# Epoch 184/300
# 50/50 [==============================] - 1s 12ms/step - loss: 0.1709 - Bal_loss: 0.2218 - Wey_loss: 0.1596 - Ratio_loss: 1.6615e-04 - val_loss: 0.0756 - val_Bal_loss: 0.0716 - val_Wey_loss: 0.1076 - val_Ratio_loss: 1.1738e-04
# Epoch 185/300
# 50/50 [==============================] - 1s 17ms/step - loss: 0.1679 - Bal_loss: 0.2154 - Wey_loss: 0.1701 - Ratio_loss: 1.2701e-04 - val_loss: 0.1384 - val_Bal_loss: 0.1754 - val_Wey_loss: 0.1177 - val_Ratio_loss: 1.1731e-04
# Epoch 186/300
# 50/50 [==============================] - 1s 17ms/step - loss: 0.1761 - Bal_loss: 0.2317 - Wey_loss: 0.1569 - Ratio_loss: 1.6613e-04 - val_loss: 0.1622 - val_Bal_loss: 0.2021 - val_Wey_loss: 0.1952 - val_Ratio_loss: 1.9560e-04
# Epoch 187/300
# 50/50 [==============================] - 1s 12ms/step - loss: 0.1864 - Bal_loss: 0.2427 - Wey_loss: 0.1940 - Ratio_loss: 2.0525e-04 - val_loss: 0.1779 - val_Bal_loss: 0.2298 - val_Wey_loss: 0.1864 - val_Ratio_loss: 2.3467e-04
# Epoch 188/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.1656 - Bal_loss: 0.2155 - Wey_loss: 0.1514 - Ratio_loss: 2.7362e-04 - val_loss: 0.3741 - val_Bal_loss: 0.5528 - val_Wey_loss: 0.2147 - val_Ratio_loss: 1.5644e-04
# Epoch 189/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.1743 - Bal_loss: 0.2249 - Wey_loss: 0.1839 - Ratio_loss: 2.1500e-04 - val_loss: 0.1034 - val_Bal_loss: 0.1127 - val_Wey_loss: 0.1488 - val_Ratio_loss: 1.1734e-04
# Epoch 190/300
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1756 - Bal_loss: 0.2298 - Wey_loss: 0.1681 - Ratio_loss: 2.0520e-04 - val_loss: 0.2472 - val_Bal_loss: 0.3489 - val_Wey_loss: 0.1705 - val_Ratio_loss: 7.8187e-05
# Epoch 191/300
# 50/50 [==============================] - 1s 10ms/step - loss: 0.1591 - Bal_loss: 0.2064 - Wey_loss: 0.1441 - Ratio_loss: 9.7713e-05 - val_loss: 0.2425 - val_Bal_loss: 0.3359 - val_Wey_loss: 0.2015 - val_Ratio_loss: 1.1732e-04
# Epoch 192/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1869 - Bal_loss: 0.2510 - Wey_loss: 0.1565 - Ratio_loss: 1.4655e-04 - val_loss: 0.2351 - val_Bal_loss: 0.3185 - val_Wey_loss: 0.2348 - val_Ratio_loss: 1.9551e-04
# Epoch 193/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.1593 - Bal_loss: 0.2045 - Wey_loss: 0.1616 - Ratio_loss: 1.8567e-04 - val_loss: 0.1896 - val_Bal_loss: 0.2403 - val_Wey_loss: 0.2503 - val_Ratio_loss: 1.5644e-04
# Epoch 194/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1821 - Bal_loss: 0.2419 - Wey_loss: 0.1669 - Ratio_loss: 1.5632e-04 - val_loss: 0.1794 - val_Bal_loss: 0.2404 - val_Wey_loss: 0.1494 - val_Ratio_loss: 1.1730e-04
# Epoch 195/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.1631 - Bal_loss: 0.2122 - Wey_loss: 0.1567 - Ratio_loss: 1.5633e-04 - val_loss: 0.1878 - val_Bal_loss: 0.2527 - val_Wey_loss: 0.1601 - val_Ratio_loss: 1.9552e-04
# Epoch 196/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1498 - Bal_loss: 0.1901 - Wey_loss: 0.1565 - Ratio_loss: 9.7702e-05 - val_loss: 0.1090 - val_Bal_loss: 0.1246 - val_Wey_loss: 0.1429 - val_Ratio_loss: 1.5643e-04
# Epoch 197/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.1350 - Bal_loss: 0.1724 - Wey_loss: 0.1163 - Ratio_loss: 1.3678e-04 - val_loss: 0.1266 - val_Bal_loss: 0.1576 - val_Wey_loss: 0.1212 - val_Ratio_loss: 1.1730e-04
# Epoch 198/300
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1412 - Bal_loss: 0.1766 - Wey_loss: 0.1532 - Ratio_loss: 1.5632e-04 - val_loss: 0.2722 - val_Bal_loss: 0.3683 - val_Wey_loss: 0.3117 - val_Ratio_loss: 1.5638e-04
# Epoch 199/300
# 50/50 [==============================] - 1s 10ms/step - loss: 0.1485 - Bal_loss: 0.1878 - Wey_loss: 0.1573 - Ratio_loss: 1.4656e-04 - val_loss: 0.1558 - val_Bal_loss: 0.1847 - val_Wey_loss: 0.2499 - val_Ratio_loss: 1.1726e-04
# Epoch 200/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.1464 - Bal_loss: 0.1873 - Wey_loss: 0.1421 - Ratio_loss: 1.1722e-04 - val_loss: 0.1914 - val_Bal_loss: 0.2259 - val_Wey_loss: 0.3618 - val_Ratio_loss: 1.1729e-04
# Epoch 201/300
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1529 - Bal_loss: 0.2009 - Wey_loss: 0.1281 - Ratio_loss: 1.8561e-04 - val_loss: 0.1345 - val_Bal_loss: 0.1445 - val_Wey_loss: 0.2833 - val_Ratio_loss: 1.1725e-04
# Epoch 202/300
# 50/50 [==============================] - 1s 10ms/step - loss: 0.1858 - Bal_loss: 0.2500 - Wey_loss: 0.1633 - Ratio_loss: 1.5634e-04 - val_loss: 0.2155 - val_Bal_loss: 0.2800 - val_Wey_loss: 0.2775 - val_Ratio_loss: 3.1271e-04
# Epoch 203/300
# ...
# Epoch 235/300
# 50/50 [==============================] - 1s 16ms/step - loss: 0.1422 - Bal_loss: 0.1847 - Wey_loss: 0.1468 - Ratio_loss: 3.9067e-05 - val_loss: 0.1352 - val_Bal_loss: 0.1696 - val_Wey_loss: 0.1678 - val_Ratio_loss: 3.9072e-05
# Epoch 236/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1502 - Bal_loss: 0.1982 - Wey_loss: 0.1451 - Ratio_loss: 1.9536e-05 - val_loss: 0.0684 - val_Bal_loss: 0.0577 - val_Wey_loss: 0.1693 - val_Ratio_loss: 7.8141e-05
# Epoch 237/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.1380 - Bal_loss: 0.1834 - Wey_loss: 0.1132 - Ratio_loss: 1.9536e-05 - val_loss: 0.2120 - val_Bal_loss: 0.2698 - val_Wey_loss: 0.3363 - val_Ratio_loss: 3.9073e-05
# Epoch 238/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.1424 - Bal_loss: 0.1876 - Wey_loss: 0.1339 - Ratio_loss: 2.9301e-05 - val_loss: 0.0703 - val_Bal_loss: 0.0613 - val_Wey_loss: 0.1713 - val_Ratio_loss: 1.9537e-04
# Epoch 239/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.1209 - Bal_loss: 0.1529 - Wey_loss: 0.1287 - Ratio_loss: 4.8834e-05 - val_loss: 0.1532 - val_Bal_loss: 0.1972 - val_Wey_loss: 0.1866 - val_Ratio_loss: 7.8142e-05
# Epoch 240/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.1353 - Bal_loss: 0.1795 - Wey_loss: 0.1150 - Ratio_loss: 3.9064e-05 - val_loss: 0.0944 - val_Bal_loss: 0.1109 - val_Wey_loss: 0.1176 - val_Ratio_loss: 3.9081e-05
# Epoch 241/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.1374 - Bal_loss: 0.1752 - Wey_loss: 0.1614 - Ratio_loss: 2.9300e-05 - val_loss: 0.1712 - val_Bal_loss: 0.2327 - val_Wey_loss: 0.1547 - val_Ratio_loss: 3.9075e-05
# Epoch 242/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1333 - Bal_loss: 0.1733 - Wey_loss: 0.1294 - Ratio_loss: 1.9534e-05 - val_loss: 0.0940 - val_Bal_loss: 0.1098 - val_Wey_loss: 0.1154 - val_Ratio_loss: 7.8149e-05
# Epoch 243/300
# 50/50 [==============================] - 1s 10ms/step - loss: 0.1748 - Bal_loss: 0.2410 - Wey_loss: 0.1372 - Ratio_loss: 2.9303e-05 - val_loss: 0.1922 - val_Bal_loss: 0.2390 - val_Wey_loss: 0.3232 - val_Ratio_loss: 3.9073e-05
# Epoch 244/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1295 - Bal_loss: 0.1658 - Wey_loss: 0.1346 - Ratio_loss: 3.9067e-05 - val_loss: 0.0796 - val_Bal_loss: 0.0880 - val_Wey_loss: 0.1044 - val_Ratio_loss: 7.8143e-05
# Epoch 245/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1268 - Bal_loss: 0.1630 - Wey_loss: 0.1290 - Ratio_loss: 1.9534e-05 - val_loss: 0.1762 - val_Bal_loss: 0.2305 - val_Wey_loss: 0.2199 - val_Ratio_loss: 7.8141e-05
# Epoch 246/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.1197 - Bal_loss: 0.1551 - Wey_loss: 0.1084 - Ratio_loss: 3.9067e-05 - val_loss: 0.0743 - val_Bal_loss: 0.0801 - val_Wey_loss: 0.1055 - val_Ratio_loss: 3.9070e-05
# Epoch 247/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1180 - Bal_loss: 0.1538 - Wey_loss: 0.1012 - Ratio_loss: 3.9067e-05 - val_loss: 0.1460 - val_Bal_loss: 0.1809 - val_Wey_loss: 0.2193 - val_Ratio_loss: 3.9071e-05
# Epoch 248/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1496 - Bal_loss: 0.1975 - Wey_loss: 0.1548 - Ratio_loss: 3.9067e-05 - val_loss: 0.1921 - val_Bal_loss: 0.2570 - val_Wey_loss: 0.2219 - val_Ratio_loss: 7.8137e-05
# Epoch 249/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.1490 - Bal_loss: 0.2000 - Wey_loss: 0.1323 - Ratio_loss: 5.8604e-05 - val_loss: 0.2073 - val_Bal_loss: 0.2768 - val_Wey_loss: 0.2545 - val_Ratio_loss: 7.8154e-05
# Epoch 250/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1422 - Bal_loss: 0.1895 - Wey_loss: 0.1274 - Ratio_loss: 4.8837e-05 - val_loss: 0.1127 - val_Bal_loss: 0.1497 - val_Wey_loss: 0.0711 - val_Ratio_loss: 7.8152e-05
# Epoch 251/300
# 50/50 [==============================] - 1s 10ms/step - loss: 0.1344 - Bal_loss: 0.1773 - Wey_loss: 0.1233 - Ratio_loss: 3.9069e-05 - val_loss: 0.1092 - val_Bal_loss: 0.1436 - val_Wey_loss: 0.0732 - val_Ratio_loss: 7.8149e-05
# Epoch 252/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.1599 - Bal_loss: 0.2202 - Wey_loss: 0.1220 - Ratio_loss: 7.8133e-05 - val_loss: 0.1463 - val_Bal_loss: 0.1879 - val_Wey_loss: 0.1798 - val_Ratio_loss: 7.8145e-05
# Epoch 253/300
# 50/50 [==============================] - 1s 10ms/step - loss: 0.1298 - Bal_loss: 0.1679 - Wey_loss: 0.1349 - Ratio_loss: 1.9535e-05 - val_loss: 0.1639 - val_Bal_loss: 0.2281 - val_Wey_loss: 0.1158 - val_Ratio_loss: 7.8145e-05
# Epoch 254/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.1318 - Bal_loss: 0.1736 - Wey_loss: 0.1231 - Ratio_loss: 3.9066e-05 - val_loss: 0.1021 - val_Bal_loss: 0.1190 - val_Wey_loss: 0.1534 - val_Ratio_loss: 7.8140e-05
# Epoch 255/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.1349 - Bal_loss: 0.1777 - Wey_loss: 0.1298 - Ratio_loss: 7.8136e-05 - val_loss: 0.1326 - val_Bal_loss: 0.1778 - val_Wey_loss: 0.1065 - val_Ratio_loss: 7.8144e-05
# Epoch 256/300
# 50/50 [==============================] - 1s 10ms/step - loss: 0.1265 - Bal_loss: 0.1658 - Wey_loss: 0.1177 - Ratio_loss: 2.9301e-05 - val_loss: 0.1505 - val_Bal_loss: 0.1983 - val_Wey_loss: 0.1627 - val_Ratio_loss: 7.8137e-05
# Epoch 257/300
# 50/50 [==============================] - 1s 13ms/step - loss: 0.1359 - Bal_loss: 0.1816 - Wey_loss: 0.1181 - Ratio_loss: 2.9300e-05 - val_loss: 0.1703 - val_Bal_loss: 0.2283 - val_Wey_loss: 0.1828 - val_Ratio_loss: 7.8139e-05
# Epoch 258/300
# 50/50 [==============================] - 1s 14ms/step - loss: 0.1296 - Bal_loss: 0.1705 - Wey_loss: 0.1234 - Ratio_loss: 3.9067e-05 - val_loss: 0.1262 - val_Bal_loss: 0.1517 - val_Wey_loss: 0.2008 - val_Ratio_loss: 3.9068e-05
# Epoch 259/300
# 50/50 [==============================] - 1s 14ms/step - loss: 0.1466 - Bal_loss: 0.1986 - Wey_loss: 0.1241 - Ratio_loss: 3.9065e-05 - val_loss: 0.1335 - val_Bal_loss: 0.1467 - val_Wey_loss: 0.3051 - val_Ratio_loss: 7.8137e-05
# Epoch 260/300
# 50/50 [==============================] - 1s 13ms/step - loss: 0.1437 - Bal_loss: 0.1904 - Wey_loss: 0.1441 - Ratio_loss: 4.8834e-05 - val_loss: 0.1505 - val_Bal_loss: 0.1596 - val_Wey_loss: 0.3979 - val_Ratio_loss: 7.8143e-05
# Epoch 261/300
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1312 - Bal_loss: 0.1739 - Wey_loss: 0.1192 - Ratio_loss: 2.9299e-05 - val_loss: 0.0900 - val_Bal_loss: 0.1056 - val_Wey_loss: 0.1179 - val_Ratio_loss: 7.8138e-05
# Epoch 262/300
# 50/50 [==============================] - 1s 10ms/step - loss: 0.1305 - Bal_loss: 0.1737 - Wey_loss: 0.1141 - Ratio_loss: 6.8364e-05 - val_loss: 0.1507 - val_Bal_loss: 0.2088 - val_Wey_loss: 0.1060 - val_Ratio_loss: 7.8137e-05
# Epoch 263/300
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1212 - Bal_loss: 0.1600 - Wey_loss: 0.1037 - Ratio_loss: 3.9064e-05 - val_loss: 0.0597 - val_Bal_loss: 0.0612 - val_Wey_loss: 0.0827 - val_Ratio_loss: 7.8142e-05
# Epoch 264/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.1322 - Bal_loss: 0.1753 - Wey_loss: 0.1242 - Ratio_loss: 4.8832e-05 - val_loss: 0.2148 - val_Bal_loss: 0.2985 - val_Wey_loss: 0.2106 - val_Ratio_loss: 1.1721e-04
# Epoch 265/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.1326 - Bal_loss: 0.1760 - Wey_loss: 0.1231 - Ratio_loss: 4.8834e-05 - val_loss: 0.0870 - val_Bal_loss: 0.1076 - val_Wey_loss: 0.0772 - val_Ratio_loss: 7.8142e-05
# Epoch 266/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.1281 - Bal_loss: 0.1681 - Wey_loss: 0.1265 - Ratio_loss: 3.9065e-05 - val_loss: 0.1419 - val_Bal_loss: 0.1853 - val_Wey_loss: 0.1606 - val_Ratio_loss: 7.8132e-05
# Epoch 267/300
# 50/50 [==============================] - 1s 10ms/step - loss: 0.1383 - Bal_loss: 0.1850 - Wey_loss: 0.1258 - Ratio_loss: 4.8831e-05 - val_loss: 0.1286 - val_Bal_loss: 0.1440 - val_Wey_loss: 0.2735 - val_Ratio_loss: 1.9535e-04
# Epoch 268/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.1403 - Bal_loss: 0.1877 - Wey_loss: 0.1269 - Ratio_loss: 2.9298e-05 - val_loss: 0.1669 - val_Bal_loss: 0.1865 - val_Wey_loss: 0.4000 - val_Ratio_loss: 1.1720e-04
# Epoch 269/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.1188 - Bal_loss: 0.1523 - Wey_loss: 0.1272 - Ratio_loss: 1.9532e-05 - val_loss: 0.0884 - val_Bal_loss: 0.0935 - val_Wey_loss: 0.1791 - val_Ratio_loss: 7.8128e-05
# Epoch 270/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1109 - Bal_loss: 0.1384 - Wey_loss: 0.1362 - Ratio_loss: 1.9532e-05 - val_loss: 0.1220 - val_Bal_loss: 0.1453 - val_Wey_loss: 0.2054 - val_Ratio_loss: 7.8131e-05
# Epoch 271/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.1230 - Bal_loss: 0.1612 - Wey_loss: 0.1210 - Ratio_loss: 9.7662e-06 - val_loss: 0.1124 - val_Bal_loss: 0.1382 - val_Wey_loss: 0.1517 - val_Ratio_loss: 3.9063e-05
# Epoch 272/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1331 - Bal_loss: 0.1765 - Wey_loss: 0.1297 - Ratio_loss: 0.0000e+00 - val_loss: 0.0856 - val_Bal_loss: 0.1053 - val_Wey_loss: 0.0838 - val_Ratio_loss: 3.9064e-05
# Epoch 273/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1192 - Bal_loss: 0.1562 - Wey_loss: 0.1147 - Ratio_loss: 3.9065e-05 - val_loss: 0.0895 - val_Bal_loss: 0.1048 - val_Wey_loss: 0.1254 - val_Ratio_loss: 0.0000e+00
# Epoch 274/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.1390 - Bal_loss: 0.1875 - Wey_loss: 0.1233 - Ratio_loss: 1.9532e-05 - val_loss: 0.1269 - val_Bal_loss: 0.1713 - val_Wey_loss: 0.0989 - val_Ratio_loss: 7.8128e-05
# Epoch 275/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.1137 - Bal_loss: 0.1469 - Wey_loss: 0.1144 - Ratio_loss: 3.9065e-05 - val_loss: 0.1456 - val_Bal_loss: 0.2014 - val_Wey_loss: 0.1065 - val_Ratio_loss: 7.8130e-05
# Epoch 276/300
# 50/50 [==============================] - 1s 10ms/step - loss: 0.1567 - Bal_loss: 0.2183 - Wey_loss: 0.1176 - Ratio_loss: 2.9299e-05 - val_loss: 0.1014 - val_Bal_loss: 0.1293 - val_Wey_loss: 0.0989 - val_Ratio_loss: 7.8143e-05
# Epoch 277/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1177 - Bal_loss: 0.1505 - Wey_loss: 0.1354 - Ratio_loss: 9.7667e-06 - val_loss: 0.1509 - val_Bal_loss: 0.2201 - val_Wey_loss: 0.0512 - val_Ratio_loss: 3.9063e-05
# Epoch 278/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.1449 - Bal_loss: 0.1990 - Wey_loss: 0.1158 - Ratio_loss: 9.7658e-06 - val_loss: 0.0904 - val_Bal_loss: 0.1123 - val_Wey_loss: 0.0901 - val_Ratio_loss: 7.8133e-05
# Epoch 279/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.1269 - Bal_loss: 0.1684 - Wey_loss: 0.1182 - Ratio_loss: 9.7658e-06 - val_loss: 0.0965 - val_Bal_loss: 0.1144 - val_Wey_loss: 0.1390 - val_Ratio_loss: 7.8143e-05
# Epoch 280/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.1226 - Bal_loss: 0.1641 - Wey_loss: 0.1040 - Ratio_loss: 9.7659e-06 - val_loss: 0.1177 - val_Bal_loss: 0.1372 - val_Wey_loss: 0.2184 - val_Ratio_loss: 0.0000e+00
# Epoch 281/300
# 50/50 [==============================] - 1s 13ms/step - loss: 0.1279 - Bal_loss: 0.1695 - Wey_loss: 0.1268 - Ratio_loss: 9.7663e-06 - val_loss: 0.1437 - val_Bal_loss: 0.1762 - val_Wey_loss: 0.2435 - val_Ratio_loss: 0.0000e+00
# Epoch 282/300
# 50/50 [==============================] - 1s 13ms/step - loss: 0.1260 - Bal_loss: 0.1643 - Wey_loss: 0.1387 - Ratio_loss: 9.7659e-06 - val_loss: 0.0739 - val_Bal_loss: 0.0862 - val_Wey_loss: 0.0870 - val_Ratio_loss: 0.0000e+00
# Epoch 283/300
# 50/50 [==============================] - 1s 14ms/step - loss: 0.1259 - Bal_loss: 0.1673 - Wey_loss: 0.1205 - Ratio_loss: 2.9298e-05 - val_loss: 0.1512 - val_Bal_loss: 0.2044 - val_Wey_loss: 0.1505 - val_Ratio_loss: 0.0000e+00
# Epoch 284/300
# 50/50 [==============================] - 1s 14ms/step - loss: 0.1268 - Bal_loss: 0.1680 - Wey_loss: 0.1247 - Ratio_loss: 9.7657e-06 - val_loss: 0.1205 - val_Bal_loss: 0.1479 - val_Wey_loss: 0.1821 - val_Ratio_loss: 1.1719e-04
# Epoch 285/300
# 50/50 [==============================] - 1s 15ms/step - loss: 0.1079 - Bal_loss: 0.1412 - Wey_loss: 0.0988 - Ratio_loss: 9.7657e-06 - val_loss: 0.1378 - val_Bal_loss: 0.1871 - val_Wey_loss: 0.1246 - val_Ratio_loss: 7.8134e-05
# Epoch 286/300
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1203 - Bal_loss: 0.1596 - Wey_loss: 0.1150 - Ratio_loss: 0.0000e+00 - val_loss: 0.1751 - val_Bal_loss: 0.2442 - val_Wey_loss: 0.1553 - val_Ratio_loss: 0.0000e+00
# Epoch 287/300
# 50/50 [==============================] - 1s 12ms/step - loss: 0.1301 - Bal_loss: 0.1738 - Wey_loss: 0.1277 - Ratio_loss: 1.9532e-05 - val_loss: 0.0946 - val_Bal_loss: 0.1183 - val_Wey_loss: 0.1050 - val_Ratio_loss: 0.0000e+00
# Epoch 288/300
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1285 - Bal_loss: 0.1727 - Wey_loss: 0.1177 - Ratio_loss: 2.9298e-05 - val_loss: 0.1049 - val_Bal_loss: 0.1355 - val_Wey_loss: 0.1044 - val_Ratio_loss: 0.0000e+00
# Epoch 289/300
# 50/50 [==============================] - 1s 11ms/step - loss: 0.1208 - Bal_loss: 0.1590 - Wey_loss: 0.1222 - Ratio_loss: 2.9298e-05 - val_loss: 0.0773 - val_Bal_loss: 0.0858 - val_Wey_loss: 0.1251 - val_Ratio_loss: 0.0000e+00
# Epoch 290/300
# 50/50 [==============================] - 1s 10ms/step - loss: 0.1118 - Bal_loss: 0.1450 - Wey_loss: 0.1163 - Ratio_loss: 0.0000e+00 - val_loss: 0.1321 - val_Bal_loss: 0.1771 - val_Wey_loss: 0.1273 - val_Ratio_loss: 0.0000e+00
# Epoch 291/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1124 - Bal_loss: 0.1468 - Wey_loss: 0.1098 - Ratio_loss: 0.0000e+00 - val_loss: 0.0699 - val_Bal_loss: 0.0807 - val_Wey_loss: 0.0801 - val_Ratio_loss: 3.9063e-05
# Epoch 292/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1339 - Bal_loss: 0.1838 - Wey_loss: 0.1030 - Ratio_loss: 9.7659e-06 - val_loss: 0.1295 - val_Bal_loss: 0.1750 - val_Wey_loss: 0.1116 - val_Ratio_loss: 0.0000e+00
# Epoch 293/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.1291 - Bal_loss: 0.1748 - Wey_loss: 0.1087 - Ratio_loss: 9.7658e-06 - val_loss: 0.1242 - val_Bal_loss: 0.1610 - val_Wey_loss: 0.1436 - val_Ratio_loss: 0.0000e+00
# Epoch 294/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1271 - Bal_loss: 0.1688 - Wey_loss: 0.1248 - Ratio_loss: 0.0000e+00 - val_loss: 0.0627 - val_Bal_loss: 0.0611 - val_Wey_loss: 0.1282 - val_Ratio_loss: 3.9063e-05
# Epoch 295/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.1278 - Bal_loss: 0.1730 - Wey_loss: 0.1106 - Ratio_loss: 0.0000e+00 - val_loss: 0.1410 - val_Bal_loss: 0.2002 - val_Wey_loss: 0.0807 - val_Ratio_loss: 0.0000e+00
# Epoch 296/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1408 - Bal_loss: 0.1956 - Wey_loss: 0.1066 - Ratio_loss: 0.0000e+00 - val_loss: 0.0823 - val_Bal_loss: 0.0760 - val_Wey_loss: 0.2379 - val_Ratio_loss: 7.8127e-05
# Epoch 297/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.1438 - Bal_loss: 0.1958 - Wey_loss: 0.1353 - Ratio_loss: 3.9064e-05 - val_loss: 0.0919 - val_Bal_loss: 0.1024 - val_Wey_loss: 0.1761 - val_Ratio_loss: 3.9064e-05
# Epoch 298/300
# 50/50 [==============================] - 0s 9ms/step - loss: 0.1206 - Bal_loss: 0.1591 - Wey_loss: 0.1230 - Ratio_loss: 2.9297e-05 - val_loss: 0.0852 - val_Bal_loss: 0.0931 - val_Wey_loss: 0.1662 - val_Ratio_loss: 1.1719e-04
# Epoch 299/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.1089 - Bal_loss: 0.1423 - Wey_loss: 0.1073 - Ratio_loss: 1.9532e-05 - val_loss: 0.0561 - val_Bal_loss: 0.0428 - val_Wey_loss: 0.1758 - val_Ratio_loss: 1.1719e-04
# Epoch 300/300
# 50/50 [==============================] - 0s 10ms/step - loss: 0.1303 - Bal_loss: 0.1765 - Wey_loss: 0.1164 - Ratio_loss: 1.9532e-05 - val_loss: 0.1347 - val_Bal_loss: 0.1718 - val_Wey_loss: 0.1881 - val_Ratio_loss: 0.0000e+00

# %%
# @title **Desempeño de la red durante el entrenamiento**
plt.plot(history.history['Bal_loss'], label='Bal_loss')
plt.plot(history.history['Wey_loss'], label='Wey_loss')
plt.plot(history.history['Ratio_loss'], label='Ratio_loss')

plt.ylim([0, 2])
plt.xlabel('Epochs')
plt.ylabel('Regularized loss')
plt.legend()  # Ahora encontrará las etiquetas definidas
plt.tick_params(axis='x', labelsize=5)  # Ajusta el tamaño de las etiquetas del eje x
plt.tick_params(axis='y', labelsize=5)  # Ajusta el tamaño de las etiquetas del eje y
plt.savefig('/content/LossG.pdf', bbox_inches='tight')
plt.show()

# %%
# @title **Salidas del modelo**
def gen_w(Data_inf, Data_W, Data_T, Data_C, Data_Dc, Data_sto):
    if not all(isinstance(data, pd.DataFrame) for data in [Data_W, Data_T, Data_C, Data_Dc, Data_sto]):
        raise ValueError("All data inputs must be pandas DataFrames")

    num_nodes = len(Data_inf)
    num_wells = len(Data_W)
    wells_matrix = coo_matrix((np.ones(num_wells, ), (Data_W['node'] - 1, np.arange(num_wells))), shape=(num_nodes, num_wells))

    num_pipes = len(Data_T)
    pipe_data = np.concatenate((-1.0 * np.ones(num_pipes), np.ones(num_pipes)))
    pipe_row = pd.concat((Data_T['fnode'] - 1, Data_T['tnode'] - 1))
    pipe_col = np.concatenate(2 * [np.arange(num_pipes)])
    pipes_matrix = coo_matrix((pipe_data, (pipe_row, pipe_col)), shape=(num_nodes, num_pipes))

    num_compressors = len(Data_C)
    compressor_data = np.concatenate((-1.0 * np.ones(num_compressors), np.ones(num_compressors)))
    compressor_row = pd.concat((Data_C['fnode'] - 1, Data_C['tnode'] - 1))
    compressor_col = np.concatenate(2 * [np.arange(num_compressors)])
    compressors_matrix = coo_matrix((compressor_data, (compressor_row, compressor_col)), shape=(num_nodes, num_compressors))

    num_users = len(Data_Dc.T)
    users_matrix = hstack(num_users * [eye(num_nodes)])

    num_storages = len(Data_sto)
    storage_matrix = coo_matrix((np.ones(num_storages, ), (Data_sto['node'] - 1, np.arange(num_storages))), shape=(num_nodes, num_storages))
    storage_matrix = hstack([storage_matrix, -1.0 * storage_matrix])

    result_matrix = hstack((wells_matrix, pipes_matrix, compressors_matrix, users_matrix, storage_matrix)).toarray()

    return result_matrix

def bounded(model, X_test, s1='/content/curso_IA_CHEC/Modulo3/database/'):
    s1_path = Path(s1)
    X_test = X_test
    filepath = ['ng_case8.xlsx', 'ng_case9.xlsx', 'ng_case10.xlsx', 'ng_case11.xlsx', 'ng_case12.xlsx', 'ng_case13.xlsx', 'ng_case14.xlsx', 'ng_case15.xlsx', 'ng_caseCol_18.xlsx']
    Weymouth = pd.DataFrame()
    Balance = pd.DataFrame()
    Costos = pd.DataFrame()
    PjPi = pd.DataFrame()
    im = 0
    path = s1_path / filepath[im]

    Data_D = pd.read_excel(path, sheet_name='node.dem')
    Data_Dc = pd.read_excel(path, sheet_name='node.demcost')
    Data_W = pd.read_excel(path, sheet_name='well')
    Data_C = pd.read_excel(path, sheet_name='comp')
    Data_T = pd.read_excel(path, sheet_name='pipe')
    Data_sto = pd.read_excel(path, sheet_name='sto')

    w = gen_w(Data_D, Data_W, Data_T, Data_C, Data_Dc, Data_sto)

    model_A = tf.keras.Model(inputs=model.inputs, outputs=model.get_layer('F').output)
    model_B = tf.keras.Model(inputs=model.inputs, outputs=model.get_layer('P').output)

    Fe = model_A.predict(np.array(X_test), verbose=False)
    Pe = model_B.predict(np.array(X_test), verbose=False)

    Fwe = Fe[:, 0:1]
    Fte = Fe[:, 1:1 + len(Data_T)]
    Fce = Fe[:, 1 + len(Data_T):1 + len(Data_T) + len(Data_C)]

    return Fwe, Fte, Fce, Pe, Data_W, Data_T, Data_C, Data_D, Data_inf

def plot_graph(graph_type, Fwe, Fte, Fce, Pe, Data_W, Data_T, Data_C, Data_inf):
    fig, axs = plt.subplots(figsize=(10, 6))

    fontsize = 15
    if graph_type == 'Gas Injection':
        sns.violinplot(data=Fwe, inner='box', cut=0, color='lightgreen', ax=axs)
        axs.set_ylabel('Gas Injection [MMSCFD]', fontsize=fontsize)
        axs.set_xlabel('Injection Node', fontsize=fontsize)
        axs.plot(0, Data_W['Imax'].values, 'k*', markersize=15)
    elif graph_type == 'Gas Flow (Pipelines)':
        sns.violinplot(data=Fte, inner='box', cut=0, color='lightgreen', ax=axs)
        axs.set_ylabel('Gas Flow [MMSCFD]', fontsize=fontsize)
        axs.set_xlabel('Pipeline Node', fontsize=fontsize)
        Li = Data_T['Fg_min'].values
        Ls = Data_T['Fg_max'].values
        axs.plot(np.arange(0, len(Data_T)), Ls, 'k*', markersize=15)
        axs.plot(np.arange(0, len(Data_T)), Li, 'k*', markersize=15)
    elif graph_type == 'Gas Flow (Compressors)':
        sns.violinplot(data=Fce, inner='box', cut=0, color='lightgreen', ax=axs)
        axs.set_ylabel('Gas Flow [MMSCFD]', fontsize=fontsize)
        axs.set_xlabel('Compressor Node', fontsize=fontsize)
        Li = [0] * len(Data_C)
        Ls = Data_C['fmaxc'].values
        axs.plot(np.arange(0, len(Data_C)), Ls, 'k*', markersize=15)
    elif graph_type == 'Pressure':
        sns.violinplot(data=Pe, inner='box', cut=0, color='lightgreen', ax=axs)
        axs.set_ylabel('Pressure [psia]', fontsize=fontsize)
        axs.set_xlabel('Pressure Node', fontsize=fontsize)
        Li = Data_inf['Pmin'].values
        Ls = Data_inf['Pmax'].values
        axs.plot(np.arange(0, Pe.shape[1]), Ls + 10, 'k*', markersize=15)
        axs.plot(np.arange(0, Pe.shape[1]), Li, 'k*', markersize=15)
    plt.grid(True)
    plt.show()

# Interfaz interactiva
def interactive_plot(model, X_test, Data_inf):
    Fwe, Fte, Fce, Pe, Data_W, Data_T, Data_C, Data_D, Data_inf = bounded(model, X_test)

    graph_options = ['Gas Injection', 'Gas Flow (Pipelines)', 'Gas Flow (Compressors)', 'Pressure']
    graph_dropdown = widgets.Dropdown(options=graph_options, description='Seleccionar gráfica:')

    def update_plot(graph_type):
        plot_graph(graph_type, Fwe, Fte, Fce, Pe, Data_W, Data_T, Data_C, Data_inf)

    widgets.interact(update_plot, graph_type=graph_dropdown)

interactive_plot(model, X_test, Data_inf)
# Out:
# interactive(children=(Dropdown(description='Seleccionar gráfica:', options=('Gas Injection', 'Gas Flow (Pipeli…
